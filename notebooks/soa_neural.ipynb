# %% [markdown]
# # Deep Learning

# %% [markdown]
# This module shows an example of using a Neural Network to create a predictive model for mortality. The following is the basis for neural network algorithm.
#
# $$\underbrace{\hat{y}}_{\text{Output}} =
# \underbrace{g}_{\text{Non-linear activation function}}
# \!\left(
# \underbrace{w_0}_{\text{Bias}} +
# \underbrace{\sum_{i=1}^{m} x_i w_i}_{\text{Linear combination of inputs}}
# \right)
# $$
#
# There are several types of neural networks and a few listed below. The general process is that there is an input, which has a set of weights and a bias term, that then goes through an activation function (e.g. sigmoid, relu, softmax), which will be the neuron. These then have a loss function that is optimizing the loss. The matrix can be configured depending how deep (number of layers) and wide (number of neurons) the network should be.
#
# - **Feed Forward Neural Network (FFNN)** - This is the simplest type of neural network.
# - **Recurrent Neural Network (RNN)** - Main use is for sequential data. They allow the output of one step to be fed as input into the next step. Some drawbacks of RNN are bottleneck embedding which can be addressed using transformers, no parallelization, no long term memory due to vanishing gradients because the losses are added together for an entire sequence.
# - **Convolutional Neural Network (CNN)** - Main use is for image classification, which uses "filters" to identify small important features of a picture which would be used together to form larger interconnected features to classify an image. One caveat is that what the model trains on is what it will expect. For instance, if model only had upright heads in training data, it wouldn't be able to identify a sideways head.
#
# There are some regularlization that can happen as well:
# - **Dropout** - removes a percent of activation layers
# - **Early Stopping** - stop training before overfitting
#
# If wanting to learn more on neural networks, the following course was helpful:
# - https://introtodeeplearning.com/

# %% [markdown]
# # Import Modules

# %%
import importlib
import os
import sys

import joblib
import numpy as np
import pandas as pd
import polars as pl
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
os.chdir("../")
sys.path.insert(0, os.getcwd())

# %%
from morai.experience import charters, experience, tables
from morai.forecast import metrics, preprocessors
from morai.models import neural
from morai.utils import custom_logger, helpers

# %%
logger = custom_logger.setup_logging(__name__)

# %%
# update log level if wanting more logging
custom_logger.set_log_level("INFO")

# %%
pd.options.display.float_format = "{:,.2f}".format

# %%
# default is "plotly_mimetype+notebook", however that takes up space.
# "plotly_mimetype+notebook_connected" seems to save space
import plotly.io as pio

pio.renderers.default = "plotly_mimetype+notebook_connected"

# %% [markdown]
# # Data

# %% [markdown]
# **This `Data` section only needs to be run once.** If the file `mortality_grouped.parquet` is in the datasets folder, then can skip to step 4. Neural

# %% [markdown]
# ## Load Data

# %% [markdown]
# Partition data is much faster to load and work with in parquet format, so saving for future use.

# %%
csv_file = r"C:\Users\johnk\Desktop\nextcloud\actuarial\SOA\datasets\ILEC_2012_19 - 20240429.txt"
write_path = r"files\partition"

# %%
pl_dtypes = {
    "Observation_Year": pl.Int32,
    "Age_Ind": pl.Categorical,
    "Sex": pl.Categorical,
    "Smoker_Status": pl.Categorical,
    "Insurance_Plan": pl.Categorical,
    "Issue_Age": pl.Int32,
    "Duration": pl.Int32,
    "Face_Amount_Band": pl.Categorical,
    "Issue_Year": pl.Int32,
    "Attained_Age": pl.Int32,
    "SOA_Antp_Lvl_TP": pl.Categorical,
    "SOA_Guar_Lvl_TP": pl.Categorical,
    "SOA_Post_Lvl_Ind": pl.Categorical,
    "Slct_Ult_Ind": pl.Categorical,
    "Preferred_Class": pl.Categorical,
    "Number_of_Pfd_Classes": pl.Categorical,
    "Preferred_Indicator": pl.Categorical,
    "MIB_Flag": pl.Categorical,
    "Amount_Exposed": pl.Float64,
    "Policies_Exposed": pl.Float64,
    "Death_Claim_Amount": pl.Int64,
    "Death_Count": pl.Int64,
    "ExpDth_Amt_VBT2015": pl.Float64,
    "ExpDth_Amt_VBT2015wMI": pl.Float64,
    "ExpDth_Cnt_VBT2015": pl.Float64,
    "ExpDth_Cnt_VBT2015wMI": pl.Float64,
    "Cen2MomP1wMI_byAmt": pl.Float64,
    "Cen2MomP2wMI_byAmt": pl.Float64,
    "Cen3MomP1wMI_byAmt": pl.Float64,
    "Cen3MomP2wMI_byAmt": pl.Float64,
    "Cen3MomP3wMI_byAmt": pl.Float64,
}

# %%
lzdf = pl.read_csv(
    csv_file,
    separator="\t",
    schema_overrides=pl_dtypes,
)

# %%
# 5 minute
lzdf.write_parquet(
    write_path,
    compression='snappy',
    use_pyarrow=True,
    pyarrow_options={"partition_cols": ["Observation_Year", "Sex"]},
)

# %% [markdown]
# ## Read Data

# %%
# needs asterisks to load in all folders and files
pl_hive_path = r"files\partition\*\*\*.parquet"

# %%
variables = [
    "Observation_Year",
    "Sex",
    "Smoker_Status",
    "Insurance_Plan",
    "Issue_Age",
    "Duration",
    "Face_Amount_Band",
    "Issue_Year",
    "Attained_Age",
    "SOA_Post_Lvl_Ind",
    "Number_of_Pfd_Classes",
    "Preferred_Class",
]
measures = [
    "Amount_Exposed",
    "Policies_Exposed",
    "Death_Claim_Amount",
    "Death_Count",
    "Cen2MomP1wMI_Amt",
    "Cen2MomP2wMI_Amt",
]
columns_needed = variables + measures
columns_not_needed = [
    "SOA_Antp_Lvl_TP",
    "SOA_Guar_Lvl_TP",
    "MIB_Flag",
    "Preferred_Indicator",
    "Slct_Ult_Ind",
    "ExpDth_Amt_VBT2015",
    "ExpDth_Amt_VBT2015wMI",
    "ExpDth_Cnt_VBT2015",
    "ExpDth_Cnt_VBT2015wMI",
    "Cen3MomP1wMI_Amt",
    "Cen3MomP2wMI_Amt",
    "Cen3MomP3wMI_Amt",
    "Type_Underwriting_Requirements",
    "Substandard_Indicator",
]

# %%
# reading in the dataset
# `enable_string_cache` helps with categorical type values
pl.enable_string_cache()
lzdf = pl.scan_parquet(
    pl_hive_path,
    hive_partitioning=True,
)

# %%
initial_row_count = lzdf.select(pl.len()).collect().item()
print(
    f"row count: {initial_row_count:,} \n"
    f"exposures: {lzdf.select([pl.col('Amount_Exposed').sum()]).collect()[0,0]:,}"
)
# Out:
# row count: 45,501,036
# exposures: 105,573,155,815,950.17

# %% [markdown]
# ### Filter Data

# %%
no_values = (
    (pl.col("Amount_Exposed") != 0)
    | (pl.col("Policies_Exposed") != 0)
    | (pl.col("Death_Claim_Amount") != 0)
    | (pl.col("Death_Count") != 0)
)

# %%
no_exposure = pl.col("Amount_Exposed") <= 0

# %%
base_filters = (
    (pl.col("Issue_Age") >= 30)
    & (pl.col("Issue_Age") <=80)
    & (pl.col("Attained_Age") >=50)
    & (pl.col("SOA_Post_Lvl_Ind").is_in(["WLT", "N/A"]))
    & (pl.col("Insurance_Plan") != "Other")
    & (pl.col("Issue_Year") >= 1980)
    & (pl.col("Smoker_Status") != "U")
)

# %%
grouped_df = (
    lzdf.group_by(variables)
    .agg([pl.col(measure).sum() for measure in measures])
    .filter(no_values)
    .filter(~no_exposure)
    .filter(base_filters)
    .collect()
)

# %%
grouped_df = grouped_df.to_pandas()

# %%
grouped_df = grouped_df.sample(frac=0.1)

# %% [markdown]
# ### Clean Data

# %%
grouped_df = helpers.clean_df(grouped_df)
# Out:
#  2026-01-18 18:32:37 | morai.utils.helpers | INFO     | lowercasing the column names
#  2026-01-18 18:32:37 | morai.utils.helpers | INFO     | replacing special characters with underscores in the column names
#  2026-01-18 18:32:37 | morai.utils.helpers | INFO     | removed unused categories and reorder
#  2026-01-18 18:32:38 | morai.utils.helpers | INFO     | update index to int32
#  2026-01-18 18:32:38 | morai.utils.helpers | INFO     | dataFrame shape: (944410, 18)

# %%
grouped_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 944410 entries, 726907 to 8578578
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   observation_year       944410 non-null  int64
#  1   sex                    944410 non-null  object
#  2   smoker_status          944410 non-null  category
#  3   insurance_plan         944410 non-null  category
#  4   issue_age              944410 non-null  int32
#  5   duration               944410 non-null  int32
#  6   face_amount_band       944410 non-null  category
#  7   issue_year             944410 non-null  int32
#  8   attained_age           944410 non-null  int32
#  9   soa_post_lvl_ind       944410 non-null  category
#  10  number_of_pfd_classes  944410 non-null  category
#  11  preferred_class        944410 non-null  category
#  12  amount_exposed         944410 non-null  float64
#  13  policies_exposed       944410 non-null  float64
#  14  death_claim_amount     944410 non-null  int64
#  15  death_count            944410 non-null  int64
#  16  cen2momp1wmi_amt       944410 non-null  float64
#  17  cen2momp2wmi_amt       944410 non-null  float64
# dtypes: category(6), float64(4), int32(4), int64(3), object(1)
# memory usage: 81.1+ MB

# %%
print(
    f"row count: {len(grouped_df):,} \n"
    f"exposures: {grouped_df['amount_exposed'].sum():,}"
)
# Out:
# row count: 944,410
# exposures: 4,058,228,911,893.4976

# %% [markdown]
# ### Calculated Fields

# %%
grouped_df["class_enh"] = (
    grouped_df["number_of_pfd_classes"].astype(str)
    + "_"
    + grouped_df["preferred_class"].astype(str)
).astype("category")

# %%
grouped_df["capped_duration"] = grouped_df["duration"].clip(upper=26)
binned_face_dict = {
    "01: 0 - 9,999": "01: 0 - 24,999",
    "02: 10,000 - 24,999": "01: 0 - 24,999",
    "03: 25,000 - 49,999": "02: 25,000 - 99,999",
    "04: 50,000 - 99,999": "02: 25,000 - 99,999",
    "05: 100,000 - 249,999": "03: 100,000 - 249,999",
    "06: 250,000 - 499,999": "04: 250,000 - 4,999,999",
    "07: 500,000 - 999,999": "04: 250,000 - 4,999,999",
    "08: 1,000,000 - 2,499,999": "04: 250,000 - 4,999,999",
    "09: 2,500,000 - 4,999,999": "04: 250,000 - 4,999,999",
    "10: 5,000,000 - 9,999,999": "05: 5,000,000+",
    "11: 10,000,000+": "05: 5,000,000+",
}
grouped_df["binned_face"] = grouped_df["face_amount_band"].map(binned_face_dict)
grouped_df["binned_face"] = grouped_df["binned_face"].astype("category")

# %% [markdown]
# ### Add qx

# %%
grouped_df = tables.map_rates(
    df=grouped_df,
    rate="vbt15",
)
grouped_df["exp_amt_vbt15"] = grouped_df["qx_vbt15"] * grouped_df["amount_exposed"]
grouped_df["ae_vbt15"] = np.where(
    grouped_df["amount_exposed"] == 0,
    0,
    grouped_df["death_claim_amount"] / grouped_df["exp_amt_vbt15"],
)
# Out:
#  2026-01-18 18:32:42 | morai.experience.tables | INFO     | mapping rate: 'qx_vbt15' with format: 'soa'
#  2026-01-18 18:32:43 | morai.experience.tables | INFO     | the mapped rates are based on the following keys: ['issue_age', 'duration', 'sex', 'smoker_status']

# %%
grouped_df["qx_raw"] = np.where(
    grouped_df["amount_exposed"] == 0,
    0,
    grouped_df["death_claim_amount"] / grouped_df["amount_exposed"],
)
grouped_df["qx_raw"] = grouped_df["qx_raw"].clip(upper=1)

# %% [markdown]
# ## Write Data

# %%
# categories saves on memory
for col in grouped_df.select_dtypes(include="object").columns:
    grouped_df[col] = grouped_df[col].astype("category")

# %%
# write to file for predictive model
grouped_df.to_parquet("files/dataset/mortality_grouped.parquet")

# %%
grouped_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 944410 entries, 0 to 944409
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   observation_year       944410 non-null  int64
#  1   sex                    944410 non-null  category
#  2   smoker_status          944410 non-null  category
#  3   insurance_plan         944410 non-null  category
#  4   issue_age              944410 non-null  int32
#  5   duration               944410 non-null  int32
#  6   face_amount_band       944410 non-null  category
#  7   issue_year             944410 non-null  int32
#  8   attained_age           944410 non-null  int32
#  9   soa_post_lvl_ind       944410 non-null  category
#  10  number_of_pfd_classes  944410 non-null  category
#  11  preferred_class        944410 non-null  category
#  12  amount_exposed         944410 non-null  float64
#  13  policies_exposed       944410 non-null  float64
#  14  death_claim_amount     944410 non-null  int64
#  15  death_count            944410 non-null  int64
#  16  cen2momp1wmi_amt       944410 non-null  float64
#  17  cen2momp2wmi_amt       944410 non-null  float64
#  18  class_enh              944410 non-null  category
#  19  capped_duration        944410 non-null  int32
#  20  binned_face            944410 non-null  category
#  21  qx_vbt15               944410 non-null  float64
#  22  exp_amt_vbt15          944410 non-null  float64
#  23  ae_vbt15               944410 non-null  float64
#  24  qx_raw                 944410 non-null  float64
# dtypes: category(9), float64(8), int32(5), int64(3)
# memory usage: 105.4 MB

# %%
del grouped_df

# %% [markdown]
# # Neural

# %%
model_name = "neural"

# %% [markdown]
# ## Data

# %% [markdown]
# Process the data by:
#
# - **Encoding**
#   - categorical variables need to be encoded using ordinal, nominal, ohe, embedding
#
# - **Feature Engineering**
#   - the attained age was split into splines so the neural network was given the structure and would not need to learn from scratch
#
# - **Standardizing**
#   - it's helpful for a neural network to have standarized fields to avoid a feature to have too much weight in gradient
#
# - **Splitting**
#   - have a test/train split for validation using 20% of the data for testing

# %%
pl_parquet_path = r"files/dataset/mortality_grouped.parquet"

# %%
model_data = pl.read_parquet(pl_parquet_path, use_pyarrow=True)

# %%
model_data = model_data.to_pandas()

# %%
feature_dict = {
    "target": ["qx_raw"],
    "weight": ["amount_exposed"],
    "passthrough": [
        "duration",
        "face_amount_band",
        "insurance_plan",
    ],
    "ordinal": [
        "sex",
        "smoker_status",
        "observation_year",
    ],
    "nominal": [],
    "ohe": [
        "class_enh",
    ],
    "spline": {
        "attained_age": {"n_knots": 8, "degree": 3, "knots": "quantile"},
    },
}

# %%
preprocess_dict = preprocessors.preprocess_data(
    model_data,
    feature_dict=feature_dict,
    standardize=True,
)
# Out:
#  2026-01-18 18:32:58 | morai.forecast.preprocessors | INFO     | model target: ['qx_raw']
#  2026-01-18 18:32:58 | morai.forecast.preprocessors | INFO     | model weights: ['amount_exposed']
#  2026-01-18 18:32:58 | morai.forecast.preprocessors | INFO     | passthrough - (generally numeric): ['face_amount_band', 'insurance_plan', 'duration']
#  2026-01-18 18:32:58 | morai.forecast.preprocessors | INFO     | ordinal - ordinal encoded: ['sex', 'observation_year', 'smoker_status']
#  2026-01-18 18:32:59 | morai.forecast.preprocessors | INFO     | ohe - one hot encoded (dropping first col): ['class_enh']
#  2026-01-18 18:32:59 | morai.forecast.preprocessors | INFO     | spline - b-spline basis expansion: ['attained_age']
#  2026-01-18 18:33:00 | morai.forecast.preprocessors | INFO     | standardizing the features with StandardScaler (that excludes OHE)

# %%
X = preprocess_dict["X"]
y = preprocess_dict["y"]
weights = preprocess_dict["weights"]
mapping = preprocess_dict["mapping"]
md_encoded = preprocess_dict["md_encoded"]
model_features = preprocess_dict["model_features"]
spline_dict = preprocess_dict["spline_dict"]

X_train, X_test, y_train, y_test, weights_train, weights_test = train_test_split(
    X, y, weights, random_state=0, test_size=0.2
)

# %% [markdown]
# ## Model

# %% [markdown]
# The model is set up with the following. It was chosen to use a wide and deep path to have the model learn quickly the mortality features with a wide path. This forms the "GLM" structure. The deep path then focuses on the more nuanced relationships.
#
# - **architecture**
# 2 separate paths
#
#   - Wide Path
#     - **input layer:** (1 neuron)
#   - Deep Path
#     - **input layer:** (32 neurons) ReLU activation
#     - **hidden layer 1:** (32 neurons) ReLU activation
#     - **hidden layer 2:** (16 neurons) ReLU activation
#     - **output** (1 neuron)
#   - The prediction is then wide + deep.
#
# - **learning rate**
#   - learning rate is defined as parameter, but does decrease learning rate when loss plateaus
#   - uses the Adam optimizer
#
# - **loss**
#   - either uses a poisson or binomial loss, instead of MSE, etc.
#
# - **other features**
#   - dropout can be defined
#   - early stopping after 50 epochs of no improvement on training set
#   - initialized to use overall mortality rate

# %%
model = neural.Neural(
    task="poisson",
    embedding_cols=[
        "face_amount_band",
        "insurance_plan",
    ],
)
# Out:
#  2026-01-18 18:33:05 | morai.models.neural | INFO     | initialized Neural model with Torch
# task: poisson
# device: cpu

# %% [markdown]
# ## Embedding

# %% [markdown]
# Neural Networks are very good at understanding non-linear relationships when there is a lot of data.
#
# Embedding categorical features allow a feature to be categorized in an n-dimensional space.

# %%
model.fit(
    X=X_train,
    y=y_train,
    weights=weights_train,
    X_test=X_test,
    y_test=y_test,
    weights_test=weights_test,
    epochs=500,
    lr=0.001,
    dropout=0.0,
    weight_decay=0,
    seed=42,
)
# Out:
#  2026-01-18 18:33:08 | morai.models.neural | INFO     | non-embedding columns: ['class_enh_2_2', 'class_enh_3_1', 'class_enh_3_2', 'class_enh_3_3', 'class_enh_4_1', 'class_enh_4_2', 'class_enh_4_3', 'class_enh_4_4', 'class_enh_NA_NA', 'class_enh_U_U', 'duration', 'observation_year', 's(attained_age)_1', 's(attained_age)_2', 's(attained_age)_3', 's(attained_age)_4', 's(attained_age)_5', 's(attained_age)_6', 's(attained_age)_7', 's(attained_age)_8', 's(attained_age)_9', 'sex', 'smoker_status']
#  2026-01-18 18:33:08 | morai.models.neural | INFO     | embedding columns: ['face_amount_band', 'insurance_plan']
#  2026-01-18 18:33:08 | morai.models.neural | INFO     | dropout: 0.0
#  2026-01-18 18:33:08 | morai.models.neural | WARNING  | embedding feature 'insurance_plan' has only 6 unique values and may be better suited for one-hot encoding
#  2026-01-18 18:33:08 | morai.models.neural | INFO     | created embeddings for `{'face_amount_band': 6, 'insurance_plan': 4}`
#  2026-01-18 18:33:08 | morai.models.neural | INFO     | setting seed: `42`
#  2026-01-18 18:33:13 | morai.models.neural | INFO     | overall_mu: 0.004816121089076295
# Training:   0%|          | 0/500 [00:00<?, ?it/s]
# C:\Users\johnk\miniconda3\envs\soa\Lib\site-packages\torch\optim\lr_scheduler.py:1343: UserWarning:
#
# Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\torch\csrc\autograd\generated\python_variable_methods.cpp:837.)
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>

# %% [markdown]
# ## Predict

# %%
predictions = model.predict(X)

# %%
model_data = experience.calc_qx_exp_ae(
    model_data=model_data,
    predictions=predictions,
    model_name=model_name,
    exposure_col="amount_exposed",
    actual_col="death_claim_amount",
)

# %%
charters.chart(
    df=model_data,
    x_axis="duration",
    y_axis="ratio",
    numerator="death_claim_amount",
    denominator="exp_amt_neural",
    x_bins=8,
    type="line",
)
# Out:
#  2026-01-18 18:40:03 | morai.experience.charters | INFO     | Calculating ratio using [death_claim_amount] and [exp_amt_neural]
#  2026-01-18 18:40:03 | morai.experience.charters | INFO     | Binning feature: [duration] with 8 bins

# %%
charters.compare_rates(
    model_data,
    x_axis="attained_age",
    rates=["qx_raw", "qx_vbt15", "qx_neural"],
    weights=["amount_exposed"],
    secondary="death_claim_amount",
    y_log=False,
)
# Out:
#  2026-01-18 18:40:05 | morai.experience.charters | INFO     | The weights list is 1 long and should be 3 long. Using the first weight for all weights.

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Prediction Analysis

# %% [markdown]
# ### Train/Test Ratios

# %%
# train
charters.target(
    df=model_data.loc[X_train.index],
    target="ratio",
    cols=3,
    features=model_features,
    numerator=["death_claim_amount"],
    denominator=["exp_amt_neural"],
).show()
# Out:
#  2026-01-18 18:40:06 | morai.experience.charters | INFO     | Creating '9' target plots.

# %%
# test set
charters.target(
    df=model_data.loc[X_test.index],
    target="ratio",
    cols=3,
    features=model_features,
    numerator=["death_claim_amount"],
    denominator=["exp_amt_neural"],
).show()
# Out:
#  2026-01-18 18:40:07 | morai.experience.charters | INFO     | Creating '9' target plots.

# %% [markdown]
# ### PDP

# %%
charters.pdp(
    model=model,
    df=md_encoded[((md_encoded["duration"] <= 30))],
    x_axis="duration",
    line_color="insurance_plan",
    weight="amount_exposed",
    secondary="death_count",
    mapping=mapping,
    display=True,
)
# Out:
#  2026-01-18 18:40:07 | morai.experience.charters | INFO     | Model: [Neural] for partial dependence plot.
#  2026-01-18 18:40:07 | morai.experience.charters | INFO     | Weights: [amount_exposed]
#  2026-01-18 18:40:08 | morai.experience.charters | INFO     | x_axis: [duration] type: [standardized] center: [global]
#  2026-01-18 18:40:08 | morai.experience.charters | INFO     | Line feature: [insurance_plan] type: [passthrough]
#  2026-01-18 18:40:08 | morai.experience.charters | INFO     | Creating 234 predictions.
# Processing:   0%|          | 0/234 [00:00<?, ?combo/s]
#  2026-01-18 18:42:11 | morai.experience.charters | INFO     | Adding secondary to chart: [death_count]

# %%
charters.pdp(
    model=model,
    df=md_encoded[((md_encoded["duration"] <= 30))],
    x_axis="duration",
    line_color="insurance_plan",
    # weight="amount_exposed",
    secondary="death_count",
    mapping=mapping,
    display=True,
)
# Out:
#  2025-11-13 20:38:13 | morai.experience.charters | INFO     | Model: [Neural] for partial dependence plot.
#  2025-11-13 20:38:14 | morai.experience.charters | INFO     | x_axis: [duration] type: [standardized] center: [global]
#  2025-11-13 20:38:14 | morai.experience.charters | INFO     | Line feature: [insurance_plan] type: [passthrough]
#  2025-11-13 20:38:14 | morai.experience.charters | INFO     | Creating 234 predictions.
# Processing:   0%|          | 0/234 [00:00<?, ?combo/s]
#  2025-11-13 20:42:47 | morai.experience.charters | INFO     | Adding secondary to chart: [death_count]

# %%
charters.pdp(
    model=model,
    df=md_encoded[
        (
            md_encoded["class_enh"].isin(["2_1", "2_2"])
            & (md_encoded["insurance_plan"] == "UL")
        )
    ],
    x_axis="attained_age",
    line_color="class_enh",
    secondary="death_count",
    mapping=mapping,
    center="per_x",
    display=True,
)

# %%
charters.pdp(
    model=model,
    df=md_encoded,
    x_axis="attained_age",
    line_color="binned_face",
    secondary="death_count",
    mapping=mapping,
    center="per_x",
    display=True,
)
# Out:
#  2025-09-14 11:45:30 | morai.experience.charters | INFO     | Model: [Neural] for partial dependence plot.
#  2025-09-14 11:45:30 | morai.experience.charters | INFO     | x_axis: [attained_age] type: [standardized] center: [per_x]
#  2025-09-14 11:45:30 | morai.experience.charters | INFO     | Line feature: [binned_face] type: [passthrough]
#  2025-09-14 11:45:30 | morai.experience.charters | INFO     | Creating 320 predictions.
# Processing:   0%|          | 0/320 [00:00<?, ?combo/s]
#  2025-09-14 11:53:46 | morai.experience.charters | INFO     | Adding secondary to chart: [death_count]

# %% [markdown]
# ## SHAP Analysis

# %% [markdown]
# SHAP (SHapley Additive exPlanations) is helpful in understanding the model predictions. It should be used as an additive test, because it will not provide information on how accurate the model is.

# %%
Shap = neural.Shap(model=model, background_df=X_train, n_samples=100, seed=42)
# Out:
#  2026-01-18 12:06:07 | morai.models.neural | INFO     | creating SHAP KernelExplainer with `100` background samples and a seed of `42`

# %%
shap_values = Shap.compute_values(explain_df=X_test, n_samples=100, seed=42)
# Out:
#  2026-01-18 12:06:07 | morai.models.neural | INFO     | calculating shap_values with `100` explainer samples and a seed of `42`
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
shap.plots.bar(Shap.shap_values)

# %%
shap.summary_plot(Shap.shap_values, Shap.sample_explain_df)

# %%
shap.partial_dependence_plot(
    "duration",
    model.predict,
    Shap.sample_explain_df,
    ice=False,
    model_expected_value=True,
    feature_expected_value=True,
)

# %%
shap.plots.waterfall(Shap.shap_values[0])

# %%
shap.dependence_plot(
    "insurance_plan",
    Shap.shap_values.values,
    Shap.sample_explain_df,
    interaction_index=None,
)

# %% [markdown]
# ## Embedding Analysis

# %% [markdown]
# The column `insurance_plan` was embedded to have the neural network learn the relationships of this column naturally instead of using an encoding such as ordinal or nominal. To understand the embeddings better, the weights of the embeddings were extracted and then analyzed using cosine similarity, pca, or t-sne. As seen the embeddings are 4 dimensions.

# %%
model.embedding_get_weights("insurance_plan")
# Out:
#          dim_0  dim_1  dim_2  dim_3
# __UNK__   0.17  -0.38  -0.71  -0.55
# UL        0.06  -0.77  -0.41   0.15
# VLSG     -0.74  -0.07   0.02   0.72
# ULSG     -0.16   0.33   0.35   0.65
# Perm     -0.47   0.51  -0.40  -0.91
# VL       -0.56  -0.61  -0.24   0.15
# Term     -0.14  -0.79   0.76  -0.10

# %% [markdown]
# The relationships show that the following plans are more similar.
# - Perm, Term, VL, VLSG

# %%
model.embedding_plot_similarity("insurance_plan")

# %%
model.embedding_plot_2d("insurance_plan", method="pca")

# %%
charters.pdp(
    model=model,
    df=md_encoded[((md_encoded["duration"] <= 30))],
    x_axis="face_amount_band",
    weight="amount_exposed",
    mapping=mapping,
    display=True,
)
# Out:
#  2026-01-18 18:47:02 | morai.experience.charters | INFO     | Model: [Neural] for partial dependence plot.
#  2026-01-18 18:47:02 | morai.experience.charters | INFO     | Weights: [amount_exposed]
#  2026-01-18 18:47:02 | morai.experience.charters | INFO     | x_axis: [face_amount_band] type: [passthrough] center: [global]
#  2026-01-18 18:47:02 | morai.experience.charters | INFO     | Creating 11 predictions.
# Processing:   0%|          | 0/11 [00:00<?, ?combo/s]

# %%
model.embedding_plot_similarity("face_amount_band")

# %%
model.embedding_plot_2d("face_amount_band", method="pca")

# %%
from sklearn.metrics.pairwise import cosine_similarity
import plotly.express as px
embed_col = "face_amount_band"
weights_df = model.embedding_get_weights(embed_col)
weights_df = weights_df.drop("__UNK__", errors="ignore")
weights_df = weights_df.sort_index()

# compute cosine similarity
sim_matrix = cosine_similarity(weights_df.values)
sim_df = pd.DataFrame(
    sim_matrix, index=weights_df.index, columns=weights_df.index
)

# plot
similarity_fig = px.imshow(
    sim_df,
    title=f"Embedding Similarity: {embed_col}",
    color_continuous_scale="RdBu_r",
    zmin=-1,
    zmax=1,
)
similarity_fig

# %% [markdown]
# # Reload

# %%
import importlib

# %%
importlib.reload(neural)
# Out:
# <module 'morai.models.neural' from 'C:\\Users\\johnk\\Desktop\\github\\morai\\morai\\models\\neural.py'>
