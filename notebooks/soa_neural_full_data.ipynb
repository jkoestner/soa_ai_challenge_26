# %% [markdown]
# # Deep Learning

# %% [markdown]
# This module shows an example of using a Neural Network to create a predictive model for mortality. The following is the basis for neural network algorithm.
#
# $$\underbrace{\hat{y}}_{\text{Output}} =
# \underbrace{g}_{\text{Non-linear activation function}}
# \!\left(
# \underbrace{w_0}_{\text{Bias}} +
# \underbrace{\sum_{i=1}^{m} x_i w_i}_{\text{Linear combination of inputs}}
# \right)
# $$
#
# There are several types of neural networks and a few listed below. The general process is that there is an input, which has a set of weights and a bias term, that then goes through an activation function (e.g. sigmoid, relu, softmax), which will be the neuron. These then have a loss function that is optimizing the loss. The matrix can be configured depending how deep (number of layers) and wide (number of neurons) the network should be.
#
# - **Feed Forward Neural Network (FFNN)** - This is the simplest type of neural network.
# - **Recurrent Neural Network (RNN)** - Main use is for sequential data. They allow the output of one step to be fed as input into the next step. Some drawbacks of RNN are bottleneck embedding which can be addressed using transformers, no parallelization, no long term memory due to vanishing gradients because the losses are added together for an entire sequence.
# - **Convolutional Neural Network (CNN)** - Main use is for image classification, which uses "filters" to identify small important features of a picture which would be used together to form larger interconnected features to classify an image. One caveat is that what the model trains on is what it will expect. For instance, if model only had upright heads in training data, it wouldn't be able to identify a sideways head.
#
# There are some regularlization that can happen as well:
# - **Dropout** - removes a percent of activation layers
# - **Early Stopping** - stop training before overfitting
#
# If wanting to learn more on neural networks, the following course was helpful:
# - https://introtodeeplearning.com/

# %% [markdown]
# # Import Modules

# %%
import importlib
import os
import sys

import joblib
import numpy as np
import pandas as pd
import polars as pl
import seaborn as sns
import shap
from sklearn.model_selection import train_test_split

# %%
os.chdir("../")
sys.path.insert(0, os.getcwd())

# %%
from morai.experience import charters, experience, tables
from morai.forecast import metrics, preprocessors
from morai.models import neural
from morai.utils import custom_logger, helpers

# %%
logger = custom_logger.setup_logging(__name__)

# %%
# update log level if wanting more logging
custom_logger.set_log_level("INFO")

# %%
pd.options.display.float_format = "{:,.2f}".format

# %%
# default is "plotly_mimetype+notebook", however that takes up space.
# "plotly_mimetype+notebook_connected" seems to save space
import plotly.io as pio

pio.renderers.default = "plotly_mimetype+notebook_connected"

# %% [markdown]
# # Data

# %% [markdown]
# **This `Data` section only needs to be run once.** If the file `mortality_grouped.parquet` is in the datasets folder, then can skip to step 4. Neural

# %% [markdown]
# ## Load Data

# %% [markdown]
# Partition data is much faster to load and work with in parquet format, so saving for future use.

# %%
csv_file = r"C:\Users\johnk\Desktop\nextcloud\actuarial\SOA\datasets\ILEC_2012_19 - 20240429.txt"
write_path = r"files\partition"

# %%
pl_dtypes = {
    "Observation_Year": pl.Int32,
    "Age_Ind": pl.Categorical,
    "Sex": pl.Categorical,
    "Smoker_Status": pl.Categorical,
    "Insurance_Plan": pl.Categorical,
    "Issue_Age": pl.Int32,
    "Duration": pl.Int32,
    "Face_Amount_Band": pl.Categorical,
    "Issue_Year": pl.Int32,
    "Attained_Age": pl.Int32,
    "SOA_Antp_Lvl_TP": pl.Categorical,
    "SOA_Guar_Lvl_TP": pl.Categorical,
    "SOA_Post_Lvl_Ind": pl.Categorical,
    "Slct_Ult_Ind": pl.Categorical,
    "Preferred_Class": pl.Categorical,
    "Number_of_Pfd_Classes": pl.Categorical,
    "Preferred_Indicator": pl.Categorical,
    "MIB_Flag": pl.Categorical,
    "Amount_Exposed": pl.Float64,
    "Policies_Exposed": pl.Float64,
    "Death_Claim_Amount": pl.Int64,
    "Death_Count": pl.Int64,
    "ExpDth_Amt_VBT2015": pl.Float64,
    "ExpDth_Amt_VBT2015wMI": pl.Float64,
    "ExpDth_Cnt_VBT2015": pl.Float64,
    "ExpDth_Cnt_VBT2015wMI": pl.Float64,
    "Cen2MomP1wMI_byAmt": pl.Float64,
    "Cen2MomP2wMI_byAmt": pl.Float64,
    "Cen3MomP1wMI_byAmt": pl.Float64,
    "Cen3MomP2wMI_byAmt": pl.Float64,
    "Cen3MomP3wMI_byAmt": pl.Float64,
}

# %%
lzdf = pl.read_csv(
    csv_file,
    separator="\t",
    schema_overrides=pl_dtypes,
)

# %%
# 5 minute
lzdf.write_parquet(
    write_path,
    compression="snappy",
    use_pyarrow=True,
    pyarrow_options={"partition_cols": ["Observation_Year", "Sex"]},
)

# %% [markdown]
# ## Read Data

# %%
# needs asterisks to load in all folders and files
pl_hive_path = r"files\partition\*\*\*.parquet"

# %%
variables = [
    "Observation_Year",
    "Sex",
    "Smoker_Status",
    "Insurance_Plan",
    "Issue_Age",
    "Duration",
    "Face_Amount_Band",
    "Issue_Year",
    "Attained_Age",
    "SOA_Post_Lvl_Ind",
    "Number_of_Pfd_Classes",
    "Preferred_Class",
]
measures = [
    "Amount_Exposed",
    "Policies_Exposed",
    "Death_Claim_Amount",
    "Death_Count",
]
columns_needed = variables + measures
columns_not_needed = [
    "SOA_Antp_Lvl_TP",
    "SOA_Guar_Lvl_TP",
    "MIB_Flag",
    "Preferred_Indicator",
    "Slct_Ult_Ind",
    "ExpDth_Amt_VBT2015",
    "ExpDth_Amt_VBT2015wMI",
    "ExpDth_Cnt_VBT2015",
    "ExpDth_Cnt_VBT2015wMI",
    "Cen2MomP1wMI_Amt",
    "Cen2MomP2wMI_Amt",
    "Cen3MomP1wMI_Amt",
    "Cen3MomP2wMI_Amt",
    "Cen3MomP3wMI_Amt",
    "Type_Underwriting_Requirements",
    "Substandard_Indicator",
]

# %%
# reading in the dataset
# `enable_string_cache` helps with categorical type values
pl.enable_string_cache()
lzdf = pl.scan_parquet(
    pl_hive_path,
    hive_partitioning=True,
)

# %%
initial_row_count = lzdf.select(pl.len()).collect().item()
print(
    f"row count: {initial_row_count:,} \n"
    f"exposures: {lzdf.select([pl.col('Amount_Exposed').sum()]).collect()[0,0]:,}"
)
# Out:
# row count: 45,501,036
# exposures: 105,573,155,815,950.17

# %% [markdown]
# ### Filter Data

# %%
no_values = (
    (pl.col("Amount_Exposed") != 0)
    | (pl.col("Policies_Exposed") != 0)
    | (pl.col("Death_Claim_Amount") != 0)
    | (pl.col("Death_Count") != 0)
)

# %%
no_values_row_count = lzdf.filter(no_values).select(pl.len()).collect().item()
print(f"removing {initial_row_count-no_values_row_count:,} cells")
# Out:
# removing 219,063 cells

# %%
no_exposure = pl.col("Amount_Exposed") <= 0

# %%
no_exposure_count = (
    lzdf.filter(no_values).filter(~no_exposure).select(pl.len()).collect().item()
)
print(f"removing {no_values_row_count-no_exposure_count:,} cells")
# Out:
# removing 702 cells

# %%
base_filters = (
    (pl.col("Issue_Age") >= 30)
    & (pl.col("Issue_Age") <= 80)
    & (pl.col("Attained_Age") >= 50)
    & (pl.col("Attained_Age") <= 95)
    & (pl.col("SOA_Post_Lvl_Ind").is_in(["WLT", "N/A"]))
    & (pl.col("Insurance_Plan") != "Other")
    & (pl.col("Issue_Year") >= 1980)
    & (pl.col("Smoker_Status") != "U")
)

# %%
base_filters_count = (
    lzdf.filter(no_values)
    .filter(~no_exposure)
    .filter(~base_filters)
    .select(pl.len())
    .collect()
    .item()
)
print(f"removing {no_exposure_count-base_filters_count:,} cells")
# Out:
# removing 18,495,707 cells

# %%
grouped_df = (
    lzdf.group_by(variables)
    .agg([pl.col(measure).sum() for measure in measures])
    .filter(no_values)
    .filter(~no_exposure)
    .filter(base_filters)
    .collect()
)

# %%
grouped_df = grouped_df.to_pandas()

# %%
# sampling due to running on 16GB RAM CPU. If using a GPU or higher RAM the data would not need to be sampled.
# grouped_df = grouped_df.sample(frac=0.1, random_state=42)

# %% [markdown]
# ### Clean Data

# %%
grouped_df = helpers.clean_df(grouped_df)
# Out:
#  2026-01-21 21:36:24 | morai.utils.helpers | INFO     | lowercasing the column names
#  2026-01-21 21:36:24 | morai.utils.helpers | INFO     | replacing special characters with underscores in the column names
#  2026-01-21 21:36:24 | morai.utils.helpers | INFO     | removed unused categories and reorder
#  2026-01-21 21:36:32 | morai.utils.helpers | INFO     | update index to int32
#  2026-01-21 21:36:32 | morai.utils.helpers | INFO     | dataFrame shape: (9386630, 16)

# %%
grouped_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9386630 entries, 0 to 9386629
# Data columns (total 16 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   observation_year       int64
#  1   sex                    object
#  2   smoker_status          category
#  3   insurance_plan         category
#  4   issue_age              int32
#  5   duration               int32
#  6   face_amount_band       category
#  7   issue_year             int32
#  8   attained_age           int32
#  9   soa_post_lvl_ind       category
#  10  number_of_pfd_classes  category
#  11  preferred_class        category
#  12  amount_exposed         float64
#  13  policies_exposed       float64
#  14  death_claim_amount     int64
#  15  death_count            int64
# dtypes: category(6), float64(2), int32(4), int64(3), object(1)
# memory usage: 662.4+ MB

# %%
print(
    f"row count: {len(grouped_df):,} \n"
    f"exposures: {grouped_df['amount_exposed'].sum():,}"
)
# Out:
# row count: 9,386,630
# exposures: 40,714,555,047,710.36

# %% [markdown]
# ### Calculated Fields

# %%
grouped_df["class_enh"] = (
    grouped_df["number_of_pfd_classes"].astype(str)
    + "_"
    + grouped_df["preferred_class"].astype(str)
).astype("category")

# %%
grouped_df["capped_duration"] = grouped_df["duration"].clip(upper=26)
binned_face_dict = {
    "01: 0 - 9,999": "01: 0 - 24,999",
    "02: 10,000 - 24,999": "01: 0 - 24,999",
    "03: 25,000 - 49,999": "02: 25,000 - 99,999",
    "04: 50,000 - 99,999": "02: 25,000 - 99,999",
    "05: 100,000 - 249,999": "03: 100,000 - 249,999",
    "06: 250,000 - 499,999": "04: 250,000 - 4,999,999",
    "07: 500,000 - 999,999": "04: 250,000 - 4,999,999",
    "08: 1,000,000 - 2,499,999": "04: 250,000 - 4,999,999",
    "09: 2,500,000 - 4,999,999": "04: 250,000 - 4,999,999",
    "10: 5,000,000 - 9,999,999": "05: 5,000,000+",
    "11: 10,000,000+": "05: 5,000,000+",
}
grouped_df["binned_face"] = grouped_df["face_amount_band"].map(binned_face_dict)
grouped_df["binned_face"] = grouped_df["binned_face"].astype("category")

# %% [markdown]
# ### Add qx

# %%
grouped_df = tables.map_rates(
    df=grouped_df,
    rate="vbt15",
)
grouped_df["exp_amt_vbt15"] = grouped_df["qx_vbt15"] * grouped_df["amount_exposed"]
grouped_df["ae_vbt15"] = np.where(
    grouped_df["amount_exposed"] == 0,
    0,
    grouped_df["death_claim_amount"] / grouped_df["exp_amt_vbt15"],
)
# Out:
#  2026-01-21 21:36:50 | morai.experience.tables | INFO     | mapping rate: 'qx_vbt15' with format: 'soa'
#  2026-01-21 21:37:00 | morai.experience.tables | INFO     | the mapped rates are based on the following keys: ['issue_age', 'duration', 'sex', 'smoker_status']

# %%
grouped_df["qx_raw"] = np.where(
    grouped_df["amount_exposed"] == 0,
    0,
    grouped_df["death_claim_amount"] / grouped_df["amount_exposed"],
)
grouped_df["qx_raw"] = grouped_df["qx_raw"].clip(upper=1)

# %% [markdown]
# ## Write Data

# %%
# categories saves on memory
for col in grouped_df.select_dtypes(include="object").columns:
    grouped_df[col] = grouped_df[col].astype("category")

# %%
# write to file for predictive model
grouped_df.to_parquet("files/dataset/full_mortality_grouped.parquet")

# %%
grouped_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9386630 entries, 0 to 9386629
# Data columns (total 23 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   observation_year       int64
#  1   sex                    category
#  2   smoker_status          category
#  3   insurance_plan         category
#  4   issue_age              int32
#  5   duration               int32
#  6   face_amount_band       category
#  7   issue_year             int32
#  8   attained_age           int32
#  9   soa_post_lvl_ind       category
#  10  number_of_pfd_classes  category
#  11  preferred_class        category
#  12  amount_exposed         float64
#  13  policies_exposed       float64
#  14  death_claim_amount     int64
#  15  death_count            int64
#  16  class_enh              category
#  17  capped_duration        int32
#  18  binned_face            category
#  19  qx_vbt15               float64
#  20  exp_amt_vbt15          float64
#  21  ae_vbt15               float64
#  22  qx_raw                 float64
# dtypes: category(9), float64(6), int32(5), int64(3)
# memory usage: 904.1 MB

# %%
del grouped_df

# %% [markdown]
# # Neural

# %%
model_name = "neural"

# %% [markdown]
# ## Data

# %% [markdown]
# Process the data by:
#
# - **Encoding**
#   - categorical variables need to be encoded using ordinal, nominal, ohe, embedding
#
# - **Feature Engineering**
#   - the attained age was split into splines so the neural network was given the structure and would not need to learn from scratch
#
# - **Standardizing**
#   - it's helpful for a neural network to have standarized fields to avoid a feature to have too much weight in gradient
#
# - **Splitting**
#   - have a test/train split for validation using 20% of the data for testing

# %%
pl_parquet_path = r"files/dataset/full_mortality_grouped.parquet"

# %%
model_data = pl.read_parquet(pl_parquet_path, use_pyarrow=True)

# %%
model_data = model_data.to_pandas()

# %%
feature_dict = {
    "target": ["qx_raw"],
    "weight": ["amount_exposed"],
    "passthrough": [
        "duration",
        "face_amount_band",
    ],
    "ordinal": [
        "sex",
        "smoker_status",
        "observation_year",
    ],
    "nominal": [],
    "ohe": [
        "class_enh",
        "insurance_plan",
    ],
    "spline": {
        "attained_age": {"n_knots": 8, "degree": 3, "knots": "quantile"},
    },
}

# %%
preprocess_dict = preprocessors.preprocess_data(
    model_data,
    feature_dict=feature_dict,
    standardize=True,
)
# Out:
#  2026-01-22 03:13:32 | morai.forecast.preprocessors | INFO     | model target: ['qx_raw']
#  2026-01-22 03:13:32 | morai.forecast.preprocessors | INFO     | model weights: ['amount_exposed']
#  2026-01-22 03:13:32 | morai.forecast.preprocessors | INFO     | passthrough - (generally numeric): ['duration', 'face_amount_band']
#  2026-01-22 03:13:32 | morai.forecast.preprocessors | INFO     | ordinal - ordinal encoded: ['sex', 'observation_year', 'smoker_status']
#  2026-01-22 03:13:38 | morai.forecast.preprocessors | INFO     | ohe - one hot encoded (dropping first col): ['class_enh', 'insurance_plan']
#  2026-01-22 03:13:42 | morai.forecast.preprocessors | INFO     | spline - b-spline basis expansion: ['attained_age']
#  2026-01-22 03:13:44 | morai.forecast.preprocessors | INFO     | standardizing the features with StandardScaler (that excludes OHE)

# %%
X = preprocess_dict["X"]
y = preprocess_dict["y"]
weights = preprocess_dict["weights"]
mapping = preprocess_dict["mapping"]
md_encoded = preprocess_dict["md_encoded"]
model_features = preprocess_dict["model_features"]
spline_dict = preprocess_dict["spline_dict"]

X_train, X_test, y_train, y_test, weights_train, weights_test = train_test_split(
    X, y, weights, random_state=0, test_size=0.2
)

# %% [markdown]
# ## Model

# %% [markdown]
# The model is set up with the following. It was chosen to use a wide and deep path to have the model learn quickly the mortality features with a wide path. This forms the "GLM" structure. The deep path then focuses on the more nuanced relationships.
#
# - **architecture**
# 2 separate paths
#
#   - Wide Path
#     - **input layer:** (1 neuron)
#   - Deep Path
#     - **input layer:** (32 neurons) ReLU activation
#     - **hidden layer 1:** (32 neurons) ReLU activation
#     - **hidden layer 2:** (16 neurons) ReLU activation
#     - **output** (1 neuron)
#   - The prediction is then wide + deep.
#
# - **learning rate**
#   - learning rate is defined as parameter, but does decrease learning rate when loss plateaus
#   - uses the Adam optimizer
#
# - **loss**
#   - either uses a poisson or binomial loss, instead of MSE, etc.
#
# - **other features**
#   - dropout can be defined
#   - early stopping after 50 epochs of no improvement on training set
#   - initialized to use overall mortality rate

# %%
model = neural.Neural(
    task="poisson",
    embedding_cols=[
        "face_amount_band",
    ],
)
# Out:
#  2026-01-22 03:14:04 | morai.models.neural | INFO     | initialized Neural model with Torch
# task: poisson
# device: cuda

# %% [markdown]
# ## Embedding

# %% [markdown]
# Neural Networks are very good at understanding non-linear relationships when there is a lot of data.
#
# Embedding categorical features allow a feature to be categorized in an n-dimensional space.

# %%
# build
model_build = True
model_save = True
model_load = False

model_name = "neural"

# %%
if model_load:
    model = joblib.load(f"files/models/{model_name}.joblib")
    logger.info(f"loaded model '{model_name}'. type: {type(model)}")

# %%
if model_build:
    fig = model.fit(
        X=X_train,
        y=y_train,
        weights=weights_train,
        X_test=X_test,
        y_test=y_test,
        weights_test=weights_test,
        epochs=1000,
        lr=0.01,
        dropout=0.0,
        weight_decay=0,
        seed=42,
    )
# Out:
#  2026-01-22 03:18:18 | morai.models.neural | INFO     | setting seed: `42`
#  2026-01-22 03:18:20 | morai.models.neural | INFO     | overall_mu: 0.004735843979723085
# Training:   0%|          | 0/1000 [00:00<?, ?it/s]
#  2026-01-22 03:21:03 | morai.models.neural | INFO     | training complete with best_epoch: `997` and best_loss: `-217409.453125`

# %%
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="d96e87bf-d67e-4ca3-b387-bdfa0df2f6cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d96e87bf-d67e-4ca3-b387-bdfa0df2f6cf")) {                    Plotly.newPlot(                        "d96e87bf-d67e-4ca3-b387-bdfa0df2f6cf",                        [{"mode":"lines+markers","name":"Train Loss","y":[-199916.34375,-204924.25,-210451.015625,-214620.25,-212133.640625,-208377.3125,-211091.03125,-212581.421875,-214019.5625,-215744.046875,-215972.140625,-215734.546875,-215373.265625,-215318.890625,-215654.15625,-215864.859375,-216012.640625,-216177.8125,-216204.9375,-216224.25,-216220.78125,-216217.640625,-216268.53125,-216243.5,-216252.59375,-216192.65625,-216219.390625,-216239.375,-216233.390625,-216251.6875,-216294.8125,-216324.921875,-216351.265625,-216287.515625,-216277.84375,-216319.484375,-216330.3125,-216342.8125,-216370.5,-216339.125,-216351.703125,-216358.71875,-216357.296875,-216365.875,-216385.15625,-216353.703125,-216358.046875,-216409.34375,-216419.671875,-216381.03125,-216391.640625,-216281.046875,-216243.53125,-216361.34375,-216191.0625,-216049.71875,-216256.859375,-216345.609375,-216193.640625,-216276.96875,-216329.78125,-216338.515625,-216402.359375,-216421.984375,-216417.265625,-216447.765625,-216432.421875,-216408.921875,-216429.953125,-216416.78125,-216404.21875,-216445.15625,-216443.09375,-216415.640625,-216444.953125,-216469.546875,-216466.671875,-216477.640625,-216485.234375,-216483.84375,-216485.78125,-216482.34375,-216491.09375,-216491.09375,-216497.9375,-216495.09375,-216502.234375,-216502.125,-216511.78125,-216504.1875,-216498.1875,-216525.796875,-216527.15625,-216524.46875,-216531.3125,-216531.15625,-216536.9375,-216516.828125,-216528.9375,-216552.015625,-216556.65625,-216517.390625,-216508.875,-216532.65625,-216543.390625,-216568.046875,-216529.8125,-216519.828125,-216544.4375,-216543.671875,-216570.140625,-216542.75,-216516.765625,-216546.25,-216511.609375,-216487.546875,-216544.09375,-216517.703125,-216422.59375,-216455.890625,-216561.984375,-216484.828125,-216321.6875,-216331.96875,-216492.328125,-216585.21875,-216530.765625,-216530.921875,-216599.5625,-216541.6875,-216439.609375,-216477.65625,-216588.78125,-216541.265625,-216437.71875,-216472.734375,-216589.75,-216576.84375,-216511.171875,-216555.734375,-216619.359375,-216569.15625,-216521.390625,-216537.921875,-216557.328125,-216601.28125,-216589.40625,-216606.96875,-216618.015625,-216592.21875,-216586.5625,-216597.421875,-216634.234375,-216570.34375,-216511.984375,-216568.359375,-216607.28125,-216611.46875,-216637.375,-216637.15625,-216642.0625,-216611.671875,-216624.359375,-216624.25,-216634.515625,-216644.171875,-216625.328125,-216658.5625,-216586.03125,-216513.21875,-216583.8125,-216668.921875,-216611.921875,-216575.140625,-216603.8125,-216597.65625,-216642.21875,-216616.328125,-216608.296875,-216650.796875,-216618.09375,-216626.234375,-216615.1875,-216598.3125,-216657.4375,-216670.4375,-216664.109375,-216681.25,-216675.984375,-216678.75,-216667.8125,-216704.9375,-216687.984375,-216681.359375,-216686.515625,-216695.703125,-216703.796875,-216708.015625,-216718.171875,-216692.203125,-216703.59375,-216708.375,-216730.015625,-216703.453125,-216696.078125,-216681.953125,-216700.03125,-216705.5,-216723.21875,-216712.046875,-216711.171875,-216696.609375,-216716.84375,-216743.203125,-216748.0625,-216727.90625,-216725.859375,-216748.609375,-216759.59375,-216748.9375,-216758.21875,-216746.328125,-216745.203125,-216764.234375,-216779.375,-216758.6875,-216775.984375,-216722.53125,-216691.859375,-216778.40625,-216606.296875,-216375.5,-216445.296875,-216698.078125,-216695.953125,-216489.421 ...

# %% [markdown]
# The model here was looking to score well on training data, however this probably causes the model to overfit. The following should be considered:
# - have early stopping on test loss instead of the train loss. When the train loss decreases but the test loss increases it shows that the model may be overfitting
# - increasing the dropout rate
# - increasing the weight decay

# %%
if model_save:
    joblib.dump(model, f"files/models/{model_name}.joblib")
    logger.info(f"saved model '{model_name}'. type: {type(model)}")
# Out:
#  2026-01-22 03:21:39 | __main__ | INFO     | saved model 'neural'. type: <class 'morai.models.neural.Neural'>

# %% [markdown]
# ## Predict

# %%
predictions = model.predict(X)

# %%
model_data = experience.calc_qx_exp_ae(
    model_data=model_data,
    predictions=predictions,
    model_name=model_name,
    exposure_col="amount_exposed",
    actual_col="death_claim_amount",
)

# %%
charters.chart(
    df=model_data,
    x_axis="duration",
    y_axis="ratio",
    numerator="death_claim_amount",
    denominator="exp_amt_neural",
    x_bins=8,
    type="line",
)
# Out:
#  2026-01-22 03:21:43 | morai.experience.charters | INFO     | Calculating ratio using [death_claim_amount] and [exp_amt_neural]
#  2026-01-22 03:21:43 | morai.experience.charters | INFO     | Binning feature: [duration] with 8 bins
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="878c0ff8-5e6b-45e4-a9ea-95ca25ae529d" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("878c0ff8-5e6b-45e4-a9ea-95ca25ae529d")) {                    Plotly.newPlot(                        "878c0ff8-5e6b-45e4-a9ea-95ca25ae529d",                        [{"hovertemplate":"duration=%{x}\u003cbr\u003eratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["01~04","05~09","10~14","15~19","20~24","25~29","30~34","35~39"],"xaxis":"x","y":{"dtype":"f8","bdata":"0iW7cu837z9p2ssQOE3wP3JFlpfzZu8\u002frMmj+LKC8D9eYSjNDJDwP2bp3uc+J\u002fA\u002ftcMZ\u002floF8D+V+IC+NyHvPw=="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"t ...

#
type":"scatter","xaxis":"x2","yaxis":"y2"},{"line":{"color":"#1F77B4"},"mode":"lines","name":"ratio","showlegend":false,"x":{"dtype":"i4","bdata":"AQAAAAIAAAADAAAABAAAAAUAAAAGAAAABwAAAAgAAAAJAAAACgAAAAsAAAAMAAAADQAAAA4AAAAPAAAAEAAAABEAAAASAAAAEwAAABQAAAAVAAAAFgAAABcAAAAYAAAAGQAAABoAAAAbAAAAHAAAAB0AAAAeAAAAHwAAACAAAAAhAAAAIgAAACMAAAAkAAAAJQAAACYAAAAnAAAA"},"y":{"dtype":"f8","bdata":"A2zw+nHF5j+rxsIWgM\u002fuPyl2p4hDPfE\u002fYgtjQZnv8D8F3Y8pMPLwP1QNiwIa3vA\u002fYjnrgPDf7z8xqHYIfHvvP+UQUfICM\u002fA\u002fIAJksSeL8D8L6af61qDuP6YR1nfBZPA\u002fvwxUAmfs7j8Qwd8YirDuPy+1iFFknvA\u002foKhrrTsr8T+Jgg6SzNzvP+rAQEh3fPA\u002fXwptbiOs8D\u002fQTeCBjnvwP\u002fzr0lbEdPA\u002fKdxxID1U8D8Mga2ztPHwPxVP0O+qWvA\u002fXgCdPCZ38D+b6qMHnyTvPxecbxRGbvA\u002f0Ah2J9wb8D+eRJ9qWk7wP0BXeSmYY\u002fA\u002fB2BnTEM68D+Yu6jKB1jvPxOvuUrhGvA\u002ftdpaDs1o7z+yM2HUJEDwP\u002fdaCsDVou0\u002fu+enOY+B7T+3Vru7ph3tP39MlBI9AvY\u002f"},"type":"scatter","xaxis":"x3","yaxis":"y3"},{"line":{"color":"#1F77B4"},"mode":"lines","name":"ratio","showlegend":false,"x":["01: 0 - 9,999","02: 10,000 - 24,999","03: 25,000 - 49,999","04: 50,000 - 99,999","05: 100,000 - 249,999","06: 250,000 - 499,999","07: 500,000 - 999,999","08: 1,000,000 - 2,499,999","09: 2,500,000 - 4,999,999","10: 5,000,000 - 9,999,999","11: 10,000,000+"],"y":{"dtype":"f8","bdata":"DFAgsB9F8D\u002fCUvLNi+HvP2c8L2Hz7O8\u002fh8jv2zAE8D9VskpmWv7vP1NwuUygFvA\u002fFdZn9tgu8D8OsHgyQULwP8bSRGX1\u002fvA\u002fD82GY2+G8D+35ds5wJXvPw=="},"type":"scatter","xaxis":"x4","yaxis":"y4"},{"line":{"color":"#1F77B4"},"mode":"lines","name":"ratio","showlegend":false,"x":["Perm","Term","UL","ULSG","VL","VLSG"],"y":{"dtype":"f8","bdata":"HzsmhyY98D+j7NFWSvHvP7lXMnjcPfA\u002fzBycv3MR8D+WiDRTAKPwP6ixFoJfy\u002fA\u002f"},"type":"scatter","xaxis":"x5","yaxis":"y5"},{"line":{"color":"#1F77B4"},"mode":"lines","name":"ratio","showlegend":false,"x":{"dtype":"i2","bdata":"3AfdB94H3wfgB+EH4gfjBw=="},"y":{"dtype":"f8","bdata":"PQQlWHw+8D95cpym5hTwP3IwH7gqCvA\ ...

# %%
# test set
charters.target(
    df=model_data.loc[X_test.index],
    target="ratio",
    cols=3,
    features=model_features,
    numerator=["death_claim_amount"],
    denominator=["exp_amt_neural"],
).show()
# Out:
#  2026-01-22 03:22:16 | morai.experience.charters | INFO     | Creating '9' target plots.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="4083e856-894e-4878-9b24-8cc723f65cfc" class="plotly-graph-div" style="height:1200px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("4083e856-894e-4878-9b24-8cc723f65cfc")) {                    Plotly.newPlot(                        "4083e856-894e-4878-9b24-8cc723f65cfc",                        [{"line":{"color":"#1F77B4"},"mode":"lines","name":"ratio","showlegend
type":"scatter","xaxis":"x3","yaxis":"y3"},{"line":{"color":"#1F77B4"},"mode":"lines","name":"ratio","showlegend":false,"x":["01: 0 - 9,999","02: 10,000 - 24,999","03: 25,000 - 49,999","04: 50,000 - 99,999","05: 100,000 - 249,999","06: 250,000 - 499,999","07: 500,000 - 999,999","08: 1,000,000 - 2,499,999","09: 2,500,000 - 4,999,999","10: 5,000,000 - 9,999,999","11: 10,000,000+"],"y":{"dtype":"f8","bdata":"7vwrgv0E8D\u002fC9OTQve7vP\u002fK0fXOfHfA\u002fXlAGuP4O8D\u002fqMfUALiPwP64qfI0nE\u002fA\u002fb9HarbYe8D\u002fxqLRlq2PwP\u002fSiAzo2cO8\u002fuegtiglY7z\u002fgYkWBdDDsPw=="},"type":"scatter","xaxis":"x4","yaxis":"y4"},{"line":{"color":"#1F77B4"},"mode":"lines","name":"ratio","showlegend":false,"x":["Perm","Term","UL","ULSG","VL","VLSG"],"y":{"dtype":"f8","bdata":"ss6XuLsH8D+5A73koHDvP66B8QZp5e8\u002fF\u002fFFal1r7z8PzsPHX1rxP2qHPom5B\u002fE\u002f"},"type":"scatter","xaxis":"x5","yaxis":"y5"},{"line":{"color":"#1F77B4"},"mode":"lines","name":"ratio","showlegend":false,"x":{"dtype":"i2","bdata":"3AfdB94H3wfgB+EH4gfjBw=="},"y":{"dtype":"f8","bdata ...

# %% [markdown]
# ### PDP

# %%
charters.pdp(
    model=model,
    df=md_encoded[((md_encoded["duration"] <= 30))],
    x_axis="duration",
    line_color="insurance_plan",
    weight="amount_exposed",
    secondary="death_count",
    mapping=mapping,
    display=True,
)
# Out:
#  2026-01-22 03:23:26 | morai.experience.charters | INFO     | Model: [Neural] for partial dependence plot.
#  2026-01-22 03:23:26 | morai.experience.charters | INFO     | Weights: [amount_exposed]
#  2026-01-22 03:23:26 | morai.experience.charters | INFO     | x_axis: [duration] type: [standardized] center: [global]
#  2026-01-22 03:23:27 | morai.experience.charters | INFO     | Line feature: [insurance_plan] type: [ohe]
#  2026-01-22 03:23:28 | morai.experience.charters | INFO     | Creating 234 predictions.
# Processing:   0%|          | 0/234 [00:00<?, ?combo/s]
#  2026-01-22 03:31:42 | morai.experience.charters | INFO     | Adding secondary to chart: [death_count]
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="ef122b12-2fa6-4675-ae28-1e6d5b3cb14a" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ef122b12-2fa6-4675-ae28-1e6d5b3cb14a")) {                    Plotly.newPlot(                        "ef122b12-2fa6-4675-ae28-1e6d5b3cb14a",                        [{"line":{"color":"#FD3216"},"mode":"lines","name":"Perm","x":{"dtype":"f8","bdata":"..."},"y":{"dtype":"f8","bdata":"XqmSrv+Q1j\u002feJjU8T2zZPzIBcq20Y9w\u002fwgE44hds3z8g5CJmqD\u002fhP5pTBtSxy+I\u002fCwLw8AlV5D+ymxrWEdblP\u002fRcAUiGR+c\u002f8h9PDCKb6D972rlHvc3pP4LLbW7O3eo\u002fy\u002fZb7RbS6z96FZw9kqnsPxaWnMuMZe0\u002fmi1DUdEO7j\u002fXK67DFanuP2ah5dn6Nu8\u002fL\u002fFcbf+27z\u002fkvgsQ2RTwP\u002f50bzDKRfA\u002ft38hKqdu8D\u002fD
nrwDn9D+KuValjwP1Px3XL\u002fdmE\u002fU\u002ffQ72gJkX9T\u002f+PkxL3xH1P7YsL2a3BPU\u002foCof8pvx9D\u002f0ojB+KNv0Pwr1JhZrwvQ\u002fTjDCOtuo9D\u002fvn7Bo74\u002f0P\u002fC61dz7ePQ\u002fYp4eFwNl9D+8e0G1\u002fVP0P5Y5uqAFRfQ\u002f"},"type":"scatter","xaxis":"x","yaxis":"y"},{"line":{"color":"#FE00CE"},"mode":"lines","name":"VL","x":{"dtype":"f8","bdata":"..."},"y":{"dtype":"f8","bdata":"4KySPe0w1z8yN6o3aB7aPwBzBQUzMt0\u002f6i1dp6Qx4D\u002furp4PKNLhP8r+PYNIduM\u002fYKRsIz4c5T9VDcn8Fr3mPzu+sbDKUug\u002fd\u002ftq733X6T8I+a9VLknrP3glTNadoOw\u002f2FlAwufb7T9VtlTo6vjuP13vAJxT9e8\u002fsPl1buBo8D+03EvIbsfwPwvlXAUbGPE\u002fEPpXQtha8T\u002fk82Ijbo7xP+cyi5y4svE\u002fCMq2fPfJ8T8HAAmOr9TxP\u002fC1rFm00\u002fE\u002fO6Kgmt7J8T8Z357JwrnxP74CJmJBpPE\u002fr1hVhy2L8T+wnd1CBW\u002fxP\u002f2EkyxI ...

# %%
charters.pdp(
    model=model,
    df=md_encoded[((md_encoded["duration"] <= 30))],
    x_axis="duration",
    line_color="insurance_plan",
    # weight="amount_exposed",
    secondary="death_count",
    mapping=mapping,
    display=True,
)
# Out:
#  2026-01-22 03:43:59 | morai.experience.charters | INFO     | Model: [Neural] for partial dependence plot.
#  2026-01-22 03:43:59 | morai.experience.charters | INFO     | x_axis: [duration] type: [standardized] center: [global]
#  2026-01-22 03:44:00 | morai.experience.charters | INFO     | Line feature: [insurance_plan] type: [ohe]
#  2026-01-22 03:44:01 | morai.experience.charters | INFO     | Creating 234 predictions.
# Processing:   0%|          | 0/234 [00:00<?, ?combo/s]
#  2026-01-22 03:52:11 | morai.experience.charters | INFO     | Adding secondary to chart: [death_count]
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="4b7999ae-33fd-4f34-b9db-b09ae4ae22c7" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("4b7999ae-33fd-4f34-b9db-b09ae4ae22c7")) {                    Plotly.newPlot(                        "4b7999ae-33fd-4f34-b9db-b09ae4ae22c7",                        [{"line":{"color":"#FD3216"},"mode":"lines","name":"Perm","x":{"dtype":"f8","bdata":"..."},"y":{"dtype":"f4","bdata":"BNXSPgy36j63fQE\u002fX4wNP3JSGT\u002fYoSQ\u002fHGYvP+KeOT93RkM\u002fvjpMP61yVD9H+Fs\u002feMJiP1DWaD8jSm4\u002f3CZzPyJqdz\u002fSFXs\u002fhyp+PytagD9ZXoE\u002fTyaCP7i3gj\u002fSGIM\u002fBVGDP9Nngz9UZIM\u002fGE2DPxIogz+++YI\u002fn8WCPwKQgj9BW4I\u002frSeCP3j3gT8Yy4E\u002fRKWBP7GHgT\u002frc4E\u002f"},"type":"scatter","xaxis":"x","yaxis":"y"},{"line":{"color":"#00FE35"},"mode":"lines","name":"Term","x":{"dtype":"f8","bdata":"..."},"y":{"dtype":"
\u002fKicfh37U0T\u002fB8o+pBI3ZPyxfAGbFouA\u002f+MQ4dwh\u002f5D\u002fEKnGIS1voP4+QqZmON+w\u002fLftw1egJ8D8TLg1eCvjxP\u002flgqeYr5vM\u002f35NFb03U9T\u002fFxuH3bsL3P6v5fYCQsPk\u002fkCwaCbKe+z92X7aR04z9P12SUhr1ev8\u002foWJ3UYu0AEAUfMUVnKsBQIeVE9qsogJA+q5hnr2ZA0BtyK9izpAEQODh\u002fSbfhwVAU\u002ftL6+9+BkDGFJqv ...

# %% [markdown]
# ## SHAP Analysis

# %% [markdown]
# SHAP (SHapley Additive exPlanations) is helpful in understanding the model predictions. It should be used as an additive test, because it will not provide information on how accurate the model is.

# %%
Shap = neural.Shap(model=model, background_df=X_train, n_samples=100, seed=42)
# Out:
#  2026-01-22 03:32:15 | morai.models.neural | INFO     | creating SHAP KernelExplainer with `100` background samples and a seed of `42`

# %%
shap_values = Shap.compute_values(explain_df=X_test, n_samples=300, seed=42)
# Out:
#  2026-01-22 03:32:15 | morai.models.neural | INFO     | calculating shap_values with `300` explainer samples and a seed of `42`
#   0%|          | 0/300 [00:00<?, ?it/s]

# %%
shap.plots.bar(Shap.shap_values)

# %%
shap.summary_plot(Shap.shap_values, Shap.sample_explain_df)

# %%
shap.partial_dependence_plot(
    "duration",
    model.predict,
    Shap.sample_explain_df,
    ice=False,
    model_expected_value=True,
    feature_expected_value=True,
)

# %%
shap.plots.waterfall(Shap.shap_values[0])

# %%
shap.dependence_plot(
    "face_amount_band",
    Shap.shap_values.values,
    Shap.sample_explain_df,
    interaction_index=None,
)

# %% [markdown]
# ## Embedding Analysis

# %% [markdown]
# The column `face_amount_band` was embedded to have the neural network learn the relationships of this column naturally instead of using an encoding such as ordinal or nominal. To understand the embeddings better, the weights of the embeddings were extracted and then analyzed using cosine similarity, pca, or t-sne. As seen the embeddings are 6 dimensions.

# %%
model.embedding_get_weights("face_amount_band")
# Out:
#                            dim_0  dim_1  dim_2  dim_3  dim_4  dim_5
# __UNK__                     0.13  -0.57  -0.12  -0.53  -0.40  -0.02
# 05: 100,000 - 249,999      -0.08  -0.31  -0.37  -0.67   0.81   0.38
# 06: 250,000 - 499,999       0.09  -0.44  -0.78  -0.42   0.70  -0.13
# 04: 50,000 - 99,999        -0.29  -0.63  -0.48  -0.19   1.13  -0.14
# 07: 500,000 - 999,999       0.06  -0.38  -0.73  -0.58   0.48   0.01
# 01: 0 - 9,999              -0.64  -0.62   0.63  -0.41   1.03   0.70
# 02: 10,000 - 24,999        -0.69  -0.79   0.09  -0.04   1.14   0.07
# 11: 10,000,000+             0.78  -0.29   0.72   0.52  -0.53   0.75
# 10: 5,000,000 - 9,999,999  -0.71   0.34  -0.65   1.01   0.15   0.28
# 03: 25,000 - 49,999        -0.57  -0.51   0.19  -0.41   1.03   0.41
# 08: 1,000,000 - 2,499,999  -0.15  -0.47  -0.85  -0.44  -0.41  -0.24
# 09: 2,500,000 - 4,999,999  -0.19   0.01  -0.12  -0.69  -0.40   0.60

# %% [markdown]
# The relationships show that face amounts close to eachother are more similar to ones that are farther apart. The PCA analysis shows that the 5M+ face bands are the farthest apart from other face bands

# %%
model.embedding_plot_similarity("face_amount_band")
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="5d6fac03-c3bc-4564-9d83-95eb68868bb2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5d6fac03-c3bc-4564-9d83-95eb68868bb2")) {                    Plotly.newPlot(                        "5d6fac03-c3bc-4564-9d83-95eb68868bb2",                        [{"coloraxis":"coloraxis","name":"0","x":["01: 0 - 9,999","02: 10,000 - 24,999","03: 25,000 - 49,999","04: 50,000 - 99,999","05: 100,000 - 249,999","06: 250,000 - 499,999","07: 500,000 - 999,999","08: 1,000,000 - 2,499,999","09: 2,500,000 - 4,999,999","10: 5,000,000 - 9,999,999","11: 10,000,000+"],"y":["01: 0 - 9,999","02: 10,000 - 24,999","03: 25,000 - 49,999","04: 50,000 - 99,999","05: 100,000 - 249,999","06: 250,000 - 499,999","07: 500,000 - 999,999","08: 1,000,000 - 2,499,999","09: 2,500,000 - 4,999,999","10: 5,000,000 - 9,999,999","11: 10,000,000+"],"z":{"dtype":"f4","bdata":"AACAP0YFVz9r8nQ\u002f+s0UP7bTKj8wsYA+\u002fHd+Ph09jb5K7z0+MiK3vaoxIr1GBVc\u002fAQCAP09faz9s2V8\u002fnCooPwRJCT8FsOA+9AwivaY2Ob5eLgw+FI2vvmvydD9PX2s\u002fAACAP+OARj8eik4\u002fcAb9Po1B8j6zht+94TwGPnMigbyn+o+++s0UP2zZXz\u002fjgEY\u002fAACAP8EFSz+Ud10\u002fDtFDPzTSbz5WpVm+UNnrPZ8AC7+20yo\u002fnCooPx6KTj\u002fBBUs\u002fAACAP93SUD+tilo\u002f3xV1Pl33qz5EVQ6+1P\u002fIvjCxgD4ESQk\u002fcAb9PpR3XT\u002fd0lA\u002fAQCAP6DLdz9g3Ao\u002fEYE+ulC6AL26Xw+\u002f\u002fHd+PgWw4D6NQfI+DtFDP62KWj+gy3c\u002f\u002f\u002f9\u002fP5rGIz98xHk+6c38veKuCb8dPY2+9AwivbOG37000m8+3xV1PmDcCj+axiM\u002fAQCAPx5cvz4WjTW9s7HcvkrvPT6mNjm+4TwGPlalWb5d96s+EYE+unzEeT4eXL8+AQCAPy72eb6mvR49MiK3vV4uDD5zIoG8UNnrPURVDr5QugC96c38vRaNNb0u9nm+AQCAP8M2Vr6qMSK9FI2vvqf6j76fAAu\u002f1P\u002fIvrpfD7\u002firgm\u002fs7Hcvqa9Hj3DNla+AQCAPw==","shape":"11, 11"},"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ecolor: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111 ...

# %%
model.embedding_plot_2d("face_amount_band", method="pca")
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="cf7c6df4-6ee8-4fc0-887c-fd2c6f63e08d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("cf7c6df4-6ee8-4fc0-887c-fd2c6f63e08d")) {                    Plotly.newPlot(                        "cf7c6df4-6ee8-4fc0-887c-fd2c6f63e08d",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ecategory=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","orientation":"v","showlegend":false,"text":["05: 100,000 - 249,999","06: 250,000 - 499,999","04: 50,000 - 99,999","07: 500,000 - 999,999","01: 0 - 9,999","02: 10,000 - 24,999","11: 10,000,000+","10: 5,000,000 - 9,999,999","03: 25,000 - 49,999","08: 1,000,000 - 2,499,999","09: 2,500,000 - 4,999,999"],"x":{"dtype":"f4","bdata":"E8+yPiGXgD6XKDY\u002fHWy5PTJDIT+nMUw\u002fOEjGv0bmIb8w8SM\u002fTaYLvzhSPr8="},"xaxis":"x","y":{"dtype":"f4","bdata":"sWj\u002fvRRHKb\u002fytYG+7Agiv1XRgD\u002f1CsY+MG90P\u002fYvOr7clf4+GjRxv1GhSL0="},"yaxis":"y","type":"scatter","textposition":"top center"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size": ...

# %%
model.embedding_plot_2d("face_amount_band", method="tsne")
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="7263db03-84d1-4d4c-83d3-f7bb0665b980" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("7263db03-84d1-4d4c-83d3-f7bb0665b980")) {                    Plotly.newPlot(                        "7263db03-84d1-4d4c-83d3-f7bb0665b980",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ecategory=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","orientation":"v","showlegend":false,"text":["05: 100,000 - 249,999","06: 250,000 - 499,999","04: 50,000 - 99,999","07: 500,000 - 999,999","01: 0 - 9,999","02: 10,000 - 24,999","11: 10,000,000+","10: 5,000,000 - 9,999,999","03: 25,000 - 49,999","08: 1,000,000 - 2,499,999","09: 2,500,000 - 4,999,999"],"x":{"dtype":"f4","bdata":"tvbSwZAhNcHrJ4hCiykNw2gd6cKeQQNDKIOowoiEFELmBITCCmYRQ7YyOkI="},"xaxis":"x","y":{"dtype":"f4","bdata":"YrE4QsokVsJp525APhd+QtZiD8JJqp7Cge0Kw8CwEsPTLxRDx5OMQkm5AEM="},"yaxis":"y","type":"scatter","textposition":"top center"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}], ...

# %%
charters.pdp(
    model=model,
    df=md_encoded[((md_encoded["duration"] <= 30))],
    x_axis="face_amount_band",
    weight="amount_exposed",
    mapping=mapping,
    display=True,
)
# Out:
#  2026-01-22 03:37:05 | morai.experience.charters | INFO     | Model: [Neural] for partial dependence plot.
#  2026-01-22 03:37:05 | morai.experience.charters | INFO     | Weights: [amount_exposed]
#  2026-01-22 03:37:05 | morai.experience.charters | INFO     | x_axis: [face_amount_band] type: [passthrough] center: [global]
#  2026-01-22 03:37:06 | morai.experience.charters | INFO     | Creating 11 predictions.
# Processing:   0%|          | 0/11 [00:00<?, ?combo/s]
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="9bfd195b-1998-4e89-a2ac-2c3d97cc7f77" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("9bfd195b-1998-4e89-a2ac-2c3d97cc7f77")) {                    Plotly.newPlot(                        "9bfd195b-1998-4e89-a2ac-2c3d97cc7f77",                        [{"line":{"color":"#FD3216"},"mode":"lines","name":"Overall","x":["01: 0 - 9,999","02: 10,000 - 24,999","03: 25,000 - 49,999","04: 50,000 - 99,999","05: 100,000 - 249,999","06: 250,000 - 499,999","07: 500,000 - 999,999","08: 1,000,000 - 2,499,999","09: 2,500,000 - 4,999,999","10: 5,000,000 - 9,999,999","11: 10,000,000+"],"y":{"dtype":"f8","bdata":"IirntB0U+D9MeKXNOQn2P0q\u002fRNcKHfM\u002fiT+Ma03G8D+G\u002fp+b8qjtPySVfd+vues\u002fn\u002fl45K7+6j9mtxXUagTrP3iYiahxTeo\u002fOqy+j5T06D8YNFAJ3lbpPw=="},"type":"scatter","xaxis":"x","yaxis":"y"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{" ...

# %% [markdown]
# # Reload

# %%
import importlib

# %%
importlib.reload(neural)
