# %% [markdown]
# # Deep Learning

# %% [markdown]
# This module shows an example of using a Neural Network to create a predictive model for mortality. The following is the basis for neural network algorithm.
#
# $$\underbrace{\hat{y}}_{\text{Output}} =
# \underbrace{g}_{\text{Non-linear activation function}}
# \!\left(
# \underbrace{w_0}_{\text{Bias}} +
# \underbrace{\sum_{i=1}^{m} x_i w_i}_{\text{Linear combination of inputs}}
# \right)
# $$
#
# There are several types of neural networks and a few listed below. The general process is that there is an input, which has a set of weights and a bias term, that then goes through an activation function (e.g. sigmoid, relu, softmax), which will be the neuron. These then have a loss function that is optimizing the loss. The matrix can be configured depending how deep (number of layers) and wide (number of neurons) the network should be.
#
# - **Feed Forward Neural Network (FFNN)** - This is the simplest type of neural network.
# - **Recurrent Neural Network (RNN)** - Main use is for sequential data. They allow the output of one step to be fed as input into the next step. Some drawbacks of RNN are bottleneck embedding which can be addressed using transformers, no parallelization, no long term memory due to vanishing gradients because the losses are added together for an entire sequence.
# - **Convolutional Neural Network (CNN)** - Main use is for image classification, which uses "filters" to identify small important features of a picture which would be used together to form larger interconnected features to classify an image. One caveat is that what the model trains on is what it will expect. For instance, if model only had upright heads in training data, it wouldn't be able to identify a sideways head.
#
# There are some regularlization that can happen as well:
# - **Dropout** - removes a percent of activation layers
# - **Early Stopping** - stop training before overfitting
#
# If wanting to learn more on neural networks, the following course was helpful:
# - https://introtodeeplearning.com/

# %% [markdown]
# # Import Modules

# %%
import importlib
import os
import sys

import joblib
import numpy as np
import pandas as pd
import polars as pl
import seaborn as sns
import shap
from sklearn.model_selection import train_test_split

# %%
# use gpu for pandas
# %load_ext cudf.pandas

# %%
os.chdir("../")
sys.path.insert(0, os.getcwd())

# %%
from morai.experience import charters, experience, tables
from morai.forecast import metrics, preprocessors
from morai.models import neural
from morai.utils import custom_logger, helpers

# %%
logger = custom_logger.setup_logging(__name__)

# %%
# update log level if wanting more logging
custom_logger.set_log_level("INFO")

# %%
pd.options.display.float_format = "{:,.2f}".format

# %%
# default is "plotly_mimetype+notebook", however that takes up space.
# "plotly_mimetype+notebook_connected" seems to save space
import plotly.io as pio

pio.renderers.default = "plotly_mimetype+notebook_connected"

# %% [markdown]
# # Data

# %% [markdown]
# **This `Data` section only needs to be run once.** If the file `mortality_grouped.parquet` is in the datasets folder, then can skip to step 4. Neural

# %% [markdown]
# ## Load Data

# %% [markdown]
# Partition data is much faster to load and work with in parquet format, so saving for future use.

# %%
csv_file = r"C:\Users\johnk\Desktop\nextcloud\actuarial\SOA\datasets\ILEC_2012_19 - 20240429.txt"
write_path = r"files\partition"

# %%
pl_dtypes = {
    "Observation_Year": pl.Int32,
    "Age_Ind": pl.Categorical,
    "Sex": pl.Categorical,
    "Smoker_Status": pl.Categorical,
    "Insurance_Plan": pl.Categorical,
    "Issue_Age": pl.Int32,
    "Duration": pl.Int32,
    "Face_Amount_Band": pl.Categorical,
    "Issue_Year": pl.Int32,
    "Attained_Age": pl.Int32,
    "SOA_Antp_Lvl_TP": pl.Categorical,
    "SOA_Guar_Lvl_TP": pl.Categorical,
    "SOA_Post_Lvl_Ind": pl.Categorical,
    "Slct_Ult_Ind": pl.Categorical,
    "Preferred_Class": pl.Categorical,
    "Number_of_Pfd_Classes": pl.Categorical,
    "Preferred_Indicator": pl.Categorical,
    "MIB_Flag": pl.Categorical,
    "Amount_Exposed": pl.Float64,
    "Policies_Exposed": pl.Float64,
    "Death_Claim_Amount": pl.Int64,
    "Death_Count": pl.Int64,
    "ExpDth_Amt_VBT2015": pl.Float64,
    "ExpDth_Amt_VBT2015wMI": pl.Float64,
    "ExpDth_Cnt_VBT2015": pl.Float64,
    "ExpDth_Cnt_VBT2015wMI": pl.Float64,
    "Cen2MomP1wMI_byAmt": pl.Float64,
    "Cen2MomP2wMI_byAmt": pl.Float64,
    "Cen3MomP1wMI_byAmt": pl.Float64,
    "Cen3MomP2wMI_byAmt": pl.Float64,
    "Cen3MomP3wMI_byAmt": pl.Float64,
}

# %%
lzdf = pl.read_csv(
    csv_file,
    separator="\t",
    schema_overrides=pl_dtypes,
)

# %%
# 5 minute
lzdf.write_parquet(
    write_path,
    compression="snappy",
    use_pyarrow=True,
    pyarrow_options={"partition_cols": ["Observation_Year", "Sex"]},
)

# %% [markdown]
# ## Read Data

# %%
# needs asterisks to load in all folders and files
pl_hive_path = r"files\partition\*\*\*.parquet"

# %%
variables = [
    "Observation_Year",
    "Sex",
    "Smoker_Status",
    "Insurance_Plan",
    "Issue_Age",
    "Duration",
    "Face_Amount_Band",
    "Issue_Year",
    "Attained_Age",
    "SOA_Post_Lvl_Ind",
    "Number_of_Pfd_Classes",
    "Preferred_Class",
]
measures = [
    "Amount_Exposed",
    "Policies_Exposed",
    "Death_Claim_Amount",
    "Death_Count",
]
columns_needed = variables + measures
columns_not_needed = [
    "SOA_Antp_Lvl_TP",
    "SOA_Guar_Lvl_TP",
    "MIB_Flag",
    "Preferred_Indicator",
    "Slct_Ult_Ind",
    "ExpDth_Amt_VBT2015",
    "ExpDth_Amt_VBT2015wMI",
    "ExpDth_Cnt_VBT2015",
    "ExpDth_Cnt_VBT2015wMI",
    "Cen2MomP1wMI_Amt",
    "Cen2MomP2wMI_Amt",
    "Cen3MomP1wMI_Amt",
    "Cen3MomP2wMI_Amt",
    "Cen3MomP3wMI_Amt",
    "Type_Underwriting_Requirements",
    "Substandard_Indicator",
]

# %%
# reading in the dataset
# `enable_string_cache` helps with categorical type values
pl.enable_string_cache()
lzdf = pl.scan_parquet(
    pl_hive_path,
    hive_partitioning=True,
)

# %%
initial_row_count = lzdf.select(pl.len()).collect().item()
print(
    f"row count: {initial_row_count:,} \n"
    f"exposures: {lzdf.select([pl.col('Amount_Exposed').sum()]).collect()[0,0]:,}"
)
# Out:
# row count: 45,501,036
# exposures: 105,573,155,815,950.17

# %% [markdown]
# ### Filter Data

# %%
no_values = (
    (pl.col("Amount_Exposed") != 0)
    | (pl.col("Policies_Exposed") != 0)
    | (pl.col("Death_Claim_Amount") != 0)
    | (pl.col("Death_Count") != 0)
)

# %%
no_values_row_count = lzdf.filter(no_values).select(pl.len()).collect().item()
print(f"removing {initial_row_count-no_values_row_count:,} cells")
# Out:
# removing 219,063 cells

# %%
no_exposure = pl.col("Amount_Exposed") <= 0

# %%
no_exposure_count = (
    lzdf.filter(no_values).filter(~no_exposure).select(pl.len()).collect().item()
)
print(f"removing {no_values_row_count-no_exposure_count:,} cells")
# Out:
# removing 702 cells

# %%
base_filters = (
    (pl.col("Issue_Age") >= 30)
    & (pl.col("Issue_Age") <= 80)
    & (pl.col("Attained_Age") >= 50)
    & (pl.col("Attained_Age") <= 95)
    & (pl.col("SOA_Post_Lvl_Ind").is_in(["WLT", "N/A"]))
    & (pl.col("Insurance_Plan") != "Other")
    & (pl.col("Issue_Year") >= 1980)
    & (pl.col("Smoker_Status") != "U")
)

# %%
base_filters_count = (
    lzdf.filter(no_values)
    .filter(~no_exposure)
    .filter(~base_filters)
    .select(pl.len())
    .collect()
    .item()
)
print(f"removing {no_exposure_count-base_filters_count:,} cells")
# Out:
# removing 18,495,707 cells

# %%
grouped_df = (
    lzdf.group_by(variables)
    .agg([pl.col(measure).sum() for measure in measures])
    .filter(no_values)
    .filter(~no_exposure)
    .filter(base_filters)
    .collect()
)

# %%
grouped_df = grouped_df.to_pandas()

# %%
# sampling due to running on 16GB RAM CPU. If using a GPU or higher RAM the data would not need to be sampled.
grouped_df = grouped_df.sample(frac=0.1, random_state=42)

# %% [markdown]
# ### Clean Data

# %%
grouped_df = helpers.clean_df(grouped_df)
# Out:
#  2026-01-24 23:22:25 | morai.utils.helpers | INFO     | lowercasing the column names
#  2026-01-24 23:22:25 | morai.utils.helpers | INFO     | replacing special characters with underscores in the column names
#  2026-01-24 23:22:25 | morai.utils.helpers | INFO     | removed unused categories and reorder
#  2026-01-24 23:22:25 | morai.utils.helpers | INFO     | update index to int32
#  2026-01-24 23:22:25 | morai.utils.helpers | INFO     | dataFrame shape: (938663, 16)

# %%
grouped_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 938663 entries, 2375428 to 5371279
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   observation_year       938663 non-null  int64
#  1   sex                    938663 non-null  object
#  2   smoker_status          938663 non-null  category
#  3   insurance_plan         938663 non-null  category
#  4   issue_age              938663 non-null  int32
#  5   duration               938663 non-null  int32
#  6   face_amount_band       938663 non-null  category
#  7   issue_year             938663 non-null  int32
#  8   attained_age           938663 non-null  int32
#  9   soa_post_lvl_ind       938663 non-null  category
#  10  number_of_pfd_classes  938663 non-null  category
#  11  preferred_class        938663 non-null  category
#  12  amount_exposed         938663 non-null  float64
#  13  policies_exposed       938663 non-null  float64
#  14  death_claim_amount     938663 non-null  int64
#  15  death_count            938663 non-null  int64
# dtypes: category(6), float64(2), int32(4), int64(3), object(1)
# memory usage: 66.2+ MB

# %%
print(
    f"row count: {len(grouped_df):,} \n"
    f"exposures: {grouped_df['amount_exposed'].sum():,}"
)
# Out:
# row count: 938,663
# exposures: 4,087,318,913,123.657

# %% [markdown]
# ### Calculated Fields

# %%
grouped_df["class_enh"] = (
    grouped_df["number_of_pfd_classes"].astype(str)
    + "_"
    + grouped_df["preferred_class"].astype(str)
).astype("category")

# %%
grouped_df["capped_duration"] = grouped_df["duration"].clip(upper=26)
binned_face_dict = {
    "01: 0 - 9,999": "01: 0 - 24,999",
    "02: 10,000 - 24,999": "01: 0 - 24,999",
    "03: 25,000 - 49,999": "02: 25,000 - 99,999",
    "04: 50,000 - 99,999": "02: 25,000 - 99,999",
    "05: 100,000 - 249,999": "03: 100,000 - 249,999",
    "06: 250,000 - 499,999": "04: 250,000 - 4,999,999",
    "07: 500,000 - 999,999": "04: 250,000 - 4,999,999",
    "08: 1,000,000 - 2,499,999": "04: 250,000 - 4,999,999",
    "09: 2,500,000 - 4,999,999": "04: 250,000 - 4,999,999",
    "10: 5,000,000 - 9,999,999": "05: 5,000,000+",
    "11: 10,000,000+": "05: 5,000,000+",
}
grouped_df["binned_face"] = grouped_df["face_amount_band"].map(binned_face_dict)
grouped_df["binned_face"] = grouped_df["binned_face"].astype("category")

# %% [markdown]
# ### Add qx

# %%
grouped_df = tables.map_rates(
    df=grouped_df,
    rate="vbt15",
)
grouped_df["exp_amt_vbt15"] = grouped_df["qx_vbt15"] * grouped_df["amount_exposed"]
grouped_df["ae_vbt15"] = np.where(
    grouped_df["amount_exposed"] == 0,
    0,
    grouped_df["death_claim_amount"] / grouped_df["exp_amt_vbt15"],
)
# Out:
#  2026-01-24 23:22:29 | morai.experience.tables | INFO     | mapping rate: 'qx_vbt15' with format: 'soa'
#  2026-01-24 23:22:29 | morai.experience.tables | INFO     | the mapped rates are based on the following keys: ['issue_age', 'duration', 'sex', 'smoker_status']

# %%
grouped_df["qx_raw"] = np.where(
    grouped_df["amount_exposed"] == 0,
    0,
    grouped_df["death_claim_amount"] / grouped_df["amount_exposed"],
)
grouped_df["qx_raw"] = grouped_df["qx_raw"].clip(upper=1)

# %% [markdown]
# ## Write Data

# %%
# categories saves on memory
for col in grouped_df.select_dtypes(include="object").columns:
    grouped_df[col] = grouped_df[col].astype("category")

# %%
# write to file for predictive model
grouped_df.to_parquet("files/dataset/mortality_grouped.parquet")

# %%
grouped_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 938663 entries, 0 to 938662
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   observation_year       938663 non-null  int64
#  1   sex                    938663 non-null  category
#  2   smoker_status          938663 non-null  category
#  3   insurance_plan         938663 non-null  category
#  4   issue_age              938663 non-null  int32
#  5   duration               938663 non-null  int32
#  6   face_amount_band       938663 non-null  category
#  7   issue_year             938663 non-null  int32
#  8   attained_age           938663 non-null  int32
#  9   soa_post_lvl_ind       938663 non-null  category
#  10  number_of_pfd_classes  938663 non-null  category
#  11  preferred_class        938663 non-null  category
#  12  amount_exposed         938663 non-null  float64
#  13  policies_exposed       938663 non-null  float64
#  14  death_claim_amount     938663 non-null  int64
#  15  death_count            938663 non-null  int64
#  16  class_enh              938663 non-null  category
#  17  capped_duration        938663 non-null  int32
#  18  binned_face            938663 non-null  category
#  19  qx_vbt15               938663 non-null  float64
#  20  exp_amt_vbt15          938663 non-null  float64
#  21  ae_vbt15               938663 non-null  float64
#  22  qx_raw                 938663 non-null  float64
# dtypes: category(9), float64(6), int32(5), int64(3)
# memory usage: 90.4 MB

# %%
del grouped_df

# %% [markdown]
# # Neural

# %%
model_name = "neural"

# %% [markdown]
# ## Data

# %% [markdown]
# Process the data by:
#
# - **Encoding**
#   - categorical variables need to be encoded using ordinal, nominal, ohe, embedding
#
# - **Feature Engineering**
#   - the attained age was split into splines so the neural network was given the structure and would not need to learn from scratch
#
# - **Standardizing**
#   - it's helpful for a neural network to have standarized fields to avoid a feature to have too much weight in gradient
#
# - **Splitting**
#   - have a test/train split for validation using 2019 as the test dataset

# %%
pl_parquet_path = r"files/dataset/full_mortality_grouped.parquet"

# %%
model_data = pl.read_parquet(pl_parquet_path, use_pyarrow=True)

# %%
model_data = model_data.to_pandas()

# %%
feature_dict = {
    "target": ["qx_raw"],
    "weight": ["amount_exposed"],
    "passthrough": [
        "face_amount_band",
    ],
    "ordinal": [
        "sex",
        "smoker_status",
        "observation_year",
    ],
    "nominal": [],
    "ohe": [
        "class_enh",
        "insurance_plan",
    ],
    "spline": {
        "attained_age": {"n_knots": 8, "degree": 3, "knots": "quantile"},
        "duration": {"n_knots": 5, "degree": 3, "knots": "quantile"},
    },
}

# %%
preprocess_dict = preprocessors.preprocess_data(
    model_data,
    feature_dict=feature_dict,
    standardize=True,
)
# Out:
#  2026-01-26 04:27:31 | morai.forecast.preprocessors | INFO     | model target: ['qx_raw']
#  2026-01-26 04:27:31 | morai.forecast.preprocessors | INFO     | model weights: ['amount_exposed']
#  2026-01-26 04:27:31 | morai.forecast.preprocessors | INFO     | passthrough - (generally numeric): ['face_amount_band']
#  2026-01-26 04:27:31 | morai.forecast.preprocessors | INFO     | ordinal - ordinal encoded: ['smoker_status', 'observation_year', 'sex']
#  2026-01-26 04:27:36 | morai.forecast.preprocessors | INFO     | ohe - one hot encoded (dropping first col): ['class_enh', 'insurance_plan']
#  2026-01-26 04:27:37 | morai.forecast.preprocessors | INFO     | spline - b-spline basis expansion: ['attained_age', 'duration']
#  2026-01-26 04:27:41 | morai.forecast.preprocessors | INFO     | standardizing the features with StandardScaler (that excludes OHE)

# %%
X = preprocess_dict["X"]
y = preprocess_dict["y"]
weights = preprocess_dict["weights"]
mapping = preprocess_dict["mapping"]
md_encoded = preprocess_dict["md_encoded"]
model_features = preprocess_dict["model_features"]
spline_dict = preprocess_dict["spline_dict"]

# using a year split instead of random
# X_train, X_test, y_train, y_test, weights_train, weights_test = train_test_split(
#     X, y, weights, random_state=0, test_size=0.2
# )

test_year_mask = (model_data['observation_year'] >= 2019)
X_train = X[~test_year_mask]
X_test = X[test_year_mask]
y_train = y[~test_year_mask]
y_test = y[test_year_mask]
weights_train = weights[~test_year_mask]
weights_test = weights[test_year_mask]

# %% [markdown]
# ## Model

# %% [markdown]
# The model is set up with the following. It was chosen to use a wide and deep path to have the model learn quickly the mortality features with a wide path. This forms the "GLM" structure. The deep path then focuses on the more nuanced relationships.
#
# - **architecture**
# 2 separate paths
#
#   - Wide Path
#     - **input layer:** (1 neuron)
#   - Deep Path
#     - **input layer:** (32 neurons) ReLU activation
#     - **hidden layer 1:** (32 neurons) ReLU activation
#     - **hidden layer 2:** (16 neurons) ReLU activation
#     - **output** (1 neuron)
#   - The prediction is then wide + deep.
#
# - **learning rate**
#   - learning rate is defined as parameter, but does decrease learning rate when loss plateaus
#   - uses the Adam optimizer
#
# - **loss**
#   - either uses a poisson or binomial loss, instead of MSE, etc.
#
# - **other features**
#   - dropout can be defined
#   - early stopping after 20 epochs of no improvement on training set after a 50 epoch warmup
#   - initialized to use overall mortality rate

# %%
model = neural.Neural(
    task="poisson",
    embedding_cols=[
        "face_amount_band",
    ],
)
# Out:
#  2026-01-26 03:47:42 | morai.models.neural | INFO     | initialized Neural model with Torch
# task: poisson
# device: cuda

# %% [markdown]
# ## Embedding

# %% [markdown]
# Neural Networks are very good at understanding non-linear relationships when there is a lot of data.
#
# Embedding categorical features allow a feature to be categorized in an n-dimensional space.

# %%
# build
model_build = True
model_save = True
model_load = False

model_name = "neural"

# %%
if model_load:
    model = joblib.load(f"files/models/{model_name}.joblib")
    logger.info(f"loaded model '{model_name}'. type: {type(model)}")
# Out:
#  2026-01-26 04:28:05 | __main__ | INFO     | loaded model 'neural'. type: <class 'morai.models.neural.Neural'>

# %%
if model_build:
    fig = model.fit(
        X=X_train,
        y=y_train,
        weights=weights_train,
        X_test=X_train,
        y_test=y_train,
        weights_test=weights_train,
        epochs=1000,
        lr=0.01,
        weight_decay=0,
        seed=42,
    )
# Out:
#  2026-01-26 03:47:42 | morai.models.neural | INFO     | setting seed: `42`
#  2026-01-26 03:47:42 | morai.models.neural | INFO     | non-embedding columns: ['class_enh_2_2', 'class_enh_3_1', 'class_enh_3_2', 'class_enh_3_3', 'class_enh_4_1', 'class_enh_4_2', 'class_enh_4_3', 'class_enh_4_4', 'class_enh_NA_NA', 'class_enh_U_U', 'insurance_plan_Term', 'insurance_plan_UL', 'insurance_plan_ULSG', 'insurance_plan_VL', 'insurance_plan_VLSG', 'observation_year', 's(attained_age)_1', 's(attained_age)_2', 's(attained_age)_3', 's(attained_age)_4', 's(attained_age)_5', 's(attained_age)_6', 's(attained_age)_7', 's(attained_age)_8', 's(attained_age)_9', 's(duration)_1', 's(duration)_2', 's(duration)_3', 's(duration)_4', 's(duration)_5', 's(duration)_6', 'sex', 'smoker_status']
#  2026-01-26 03:47:42 | morai.models.neural | INFO     | embedding columns: ['face_amount_band']
#  2026-01-26 03:47:43 | morai.models.neural | INFO     | created embeddings for `{'face_amount_band': 6}`
#  2026-01-26 03:47:49 | morai.models.neural | INFO     | overall_mu: 0.004688
#  2026-01-26 03:47:49 | morai.models.neural | INFO     | epochs: 1,000, batch_size: None, lr: 0.01
#  2026-01-26 03:47:49 | morai.models.neural | INFO     | dropout: 0.0, weight_decay: 0
#  2026-01-26 03:47:49 | morai.models.neural | INFO     | early stopping: enabled, warmup_epochs: 50, max_patience: 20
# Training:   0%|          | 0/1000 [00:00<?, ?it/s]
-216317.359375,-216292.640625,-216367.453125,-216397.90625,-216372.203125,-216382.90625,-216448.890625,-216395.421875,-216455.421875,-216396.8125,-216359.546875,-216454.890625,-216477.09375,-216459.421875,-216458.046875,-216521.640625,-216412.484375,-216306.96875,-216391.9375,-216407.828125,-216434.765625,-216486.859375,-216497.703125,-216527.140625,-216522.5,-216539.453125,-216536.5625,-216500.609375,-216542.484375,-216561.75,-216554.390625,-216609.40625,-216580.1875,-216644.09375,-216623.1875,-216642.6875,-216615.890625,-216599.40625,-216672.421875,-216643.4375,-216689.125,-216634.390625,-216623.203125,-216722.328125,-216653.953125,-216681.921875,-216711.3125,-216698.75,-216723.171875,-216723.390625,-216774.078125,-2 ...

# %% [markdown]
# The model here was looking to score well on training data, however this probably causes the model to overfit. The following should be considered:
# - have early stopping on test loss instead of the train loss. When the train loss decreases but the test loss increases it shows that the model may be overfitting
# - increasing the dropout rate
# - increasing the weight decay

# %%
if model_save:
    joblib.dump(model, f"files/models/{model_name}.joblib")
    logger.info(f"saved model '{model_name}'. type: {type(model)}")
# Out:
#  2026-01-26 03:51:45 | __main__ | INFO     | saved model 'neural'. type: <class 'morai.models.neural.Neural'>

# %% [markdown]
# ## Predict

# %%
predictions = model.predict(X)

# %%
model_data = experience.calc_qx_exp_ae(
    model_data=model_data,
    predictions=predictions,
    model_name=model_name,
    exposure_col="amount_exposed",
    actual_col="death_claim_amount",
)

# %%
charters.chart(
    df=model_data,
    x_axis="duration",
    y_axis="ratio",
    numerator="death_claim_amount",
    denominator="exp_amt_neural",
    x_bins=8,
    type="line",
)
# Out:
#  2026-01-26 03:51:51 | morai.experience.charters | INFO     | Calculating ratio using [death_claim_amount] and [exp_amt_neural]
#  2026-01-26 03:51:51 | morai.experience.charters | INFO     | Binning feature: [duration] with 8 bins
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="4733ed76-3971-48d9-8cc5-3cd494d1939e" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("4733ed76-3971-48d9-8cc5-3cd494d1939e")) {                    Plotly.newPlot(                        "4733ed76-3971-48d9-8cc5-3cd494d1939e",                        [{"hovertemplate":"duration=%{x}\u003cbr\u003eratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["01~04","05~09","10~14","15~19","20~24","25~29","30~34","35~39"],"xaxis":"x","y":{"dtype":"f8","bdata":"m9WhXbZW8D8V3xSBLiDwP52jAETIEPA\u002fKqm9Ka8P8D+cXkHRXFHwP7AB1qYZD\u002fA\u002fuHFJ1Mrk7z+mzNnDt1zvPw=="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type": ...

# %%
charters.compare_rates(
    model_data,
    x_axis="attained_age",
    rates=["qx_raw", "qx_vbt15", "qx_neural"],
    weights=["amount_exposed"],
    secondary="death_claim_amount",
    y_log=False,
)
# Out:
#  2026-01-26 03:51:51 | morai.experience.charters | INFO     | The weights list is 1 long and should be 3 long. Using the first weight for all weights.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="441bf1bb-9d17-4bc4-8bf2-1f2af69cc5df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("441bf1bb-9d17-4bc4-8bf2-1f2af69cc5df")) {                    Plotly.newPlot(                        "441bf1bb-9d17-4bc4-8bf2-1f2af69cc5df",                        [{"marker":{"color":"rgba(135, 206, 250, 0.6)"},"name":"death_claim_amount","x":{"dtype":"i4","bdata":"MgAAADMAAAA0AAAANQAAADYAAAA3AAAAOAAAADkAAAA6AAAAOwAAADwAAAA9AAAAPgAAAD
Vif8D8tzxUJiMbwP8X6eZ787vA\u002fv\u002f7u9XMY8T8yMKw4rUHxP3q2dl8cavE\u002fNBKP4mmO8T9Zy5wK5K7xP3vTEBSwyvE\u002fJxRTGZzh8T82kYpPNfTxP4sV8LVUA\u002fI\u002fdP8wRLMO8j8xJCeULRfyPxB6xJtaHfI\u002fAiJRbzAh8j+djHJJMyPyP2YUDmtxI\u002fI\u002f"},"type":"scatter","xaxis":"x","yaxis":"y"},{"line":{"color":"#FED4C4"},"mode":"lines","name":"ULSG","x":{"dtype":"f8","bdata":""},"y":{"dtype":"f8","bdata":"nWOYrssn7T+pZ+cAqY3tP0xLCGWQ9u0\u002f9ohcl5ZV7j\u002fYC6GW7aPuPxBOP1sF7O4\u002fbGYemWI67z\u002fastQKNYnvP9rYj6Ar4e8\u002fIcASToUk8D+uSuxgtlrwP8beX4xgkfA\u002fpL+ar43D8D\u002ffCLRe1vLwP7DkQ0yxH\u002fE\u002ftv7D1b9I8T81fGpcYmvxP6naKBAZifE\u002fVcFbG82g8T9Q\u002fYZm\u002fLLxPySNZ0rtv\ ...

# %%
charters.pdp(
    model=model,
    df=md_encoded[((md_encoded["duration"] <= 30))],
    x_axis="duration",
    line_color="insurance_plan",
    # weight="amount_exposed",
    secondary="death_count",
    mapping=mapping,
    spline_dict=spline_dict,
    display=True,
)
# Out:
#  2026-01-26 04:03:28 | morai.experience.charters | INFO     | Model: [Neural] for partial dependence plot.
#  2026-01-26 04:03:28 | morai.experience.charters | INFO     | x_axis: [duration] type: [spline] center: [global]
#  2026-01-26 04:03:29 | morai.experience.charters | INFO     | Line feature: [insurance_plan] type: [ohe]
#  2026-01-26 04:03:29 | morai.experience.charters | INFO     | Creating 180 predictions.
# Processing:   0%|          | 0/180 [00:00<?, ?combo/s]
#  2026-01-26 04:09:37 | morai.experience.charters | INFO     | Adding secondary to chart: [death_count]
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="d8836e51-4e26-413c-9f22-21a9e6809cd0" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d8836e51-4e26-413c-9f22-21a9e6809cd0")) {                    Plotly.newPlot(                        "d8836e51-4e26-413c-9f22-21a9e6809cd0",                        [{"line":{"color":"#FD3216"},"mode":"lines","name":"Perm","x":{"dtype":"f8","bdata":""},"y":{"dtype":"f4","bdata":"RmpGP7sTST9FSEw\u002fdeFPPzCxUz+ghVc\u002fUhpbPwg8Xj+r8GA\u002frDhjPwwwZT9L92Y\u002f6a1oP1Bpaj\u002f5I2w\u002f7sxtP31Ubz+hq3A\u002fYc9xP3C2cj8ca3M\u002fxfJzPx5SdD87jnQ\u002f4ax0P8ixdD8noHQ\u002fE3p0P2BEdD8QBHQ\u002f"},"type":"scatter","xaxis":"x","yaxis":"y"},{"line":{"color":"#00FE35"},"mode":"lines","name":"Term","x":{"dtype":"f8","bdata":""},"y":{"dtype":"f4","bdata":"8ZRtPww5cT\u002fXoXU\u002fRZ56P0bdfz\u002fbhoI\u002fYvGEP83lhj+9UIg\u002fL2OJP3w6ij9d6Yo\u002fxZWLP4FijD8dR40\u002f9jOOP4EZjz+x748\u002fMKuQPwdIkT+MxZE\u002f2yWSP+9qkj\u002f8l5I\u002f27GSP6e7kj\u002fUt5I\u002fQKiSP7iMkj9RapI\u002f"},"type":"scatter","xaxis":"x","yaxis":"y"},{"line":{"color":"#6A76FC"},"mode":"lines","name":"UL","x":{"dtype":"f8","bdata":""},"y":{"dtype":"f4","bdata":"N99mP4poaT+Zm2w\u002frklwP9Y5dD8PJ3g\u002faNN7P8EPfz818oA\u002fcDGCPzRRgz8BZIQ\u002fW3+FPxq0hj9N\u002fIc\u002fv0uJP8CUij9yy4s\u002f2+OMPy\u002fYjT8pqI4\u002fwlaPP6Xnjz\u002fzXZA\u002furuQP74DkT+5OJE\u002f\u002f1uRP0RwkT9Od5E\u002f"},"type":"scatter","xaxis":"x","yaxis":"y"},{"line":{"color":"#FED4C4"},"mode":"lines","name":"ULSG","x":{"dtype":"f8","bdata":""},"y":{"dtype":"f4","bdata":"g89gP4rBYz\u002f9J2c\u002fD+NqP4jBbj+1n3I\u002f61d2P+O3eT8Wwnw\u002f04h\u002fPxsHgT9QL4I\u002fZkaDPzxVhD\u002faWIU\u002fKkmGP5gchz+f0Yc\u002fU2eIP2neiD9xOYk\u002fIH2JP\u002futiT8hzok\u002fyd2JPyHhiT+C2ok\u002f\u002f8uJP9i2iT8jnIk\u002f"},"type":"scatter","xaxis":"x","yaxis":"y"},{"line":{"color":"#FE00CE"},"mode":"lines","name":"VL","x":{"dtype":"f8","bdata":""},"y":{"dtype":"f4","bdata":"EjBVP7YEWD90XFs\u002f\u002fTBfPyxlYz\u002fKyGc\u002fVBpsPyIjcD\u002fZ1HM\u002fri93P244ej9y7Xw\u002f2UZ\u002fP8GzgD\ ...

# %% [markdown]
# ## SHAP Analysis

# %% [markdown]
# SHAP (SHapley Additive exPlanations) is helpful in understanding the model predictions. It should be used as an additive test, because it will not provide information on how accurate the model is.

# %%
X_train_pandas = X_train._fsproxy_wrapped.to_pandas()
X_test_pandas = X_test._fsproxy_wrapped.to_pandas()

# %%
Shap = neural.Shap(model=model, background_df=X_train_pandas, n_samples=25, seed=42)
# Out:
#  2026-01-26 04:38:30 | morai.models.neural | INFO     | creating SHAP KernelExplainer with `25` background samples and a seed of `42`

# %%
shap_values = Shap.compute_values(explain_df=X_test_pandas, n_samples=25, seed=42)
# Out:
#  2026-01-26 04:38:34 | morai.models.neural | INFO     | calculating shap_values with `25` explainer samples and a seed of `42`
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
shap.plots.bar(Shap.shap_values)

# %%
shap.summary_plot(Shap.shap_values, Shap.sample_explain_df)

# %%
shap.plots.waterfall(Shap.shap_values[0])

# %%
shap.dependence_plot(
    "face_amount_band",
    Shap.shap_values.values,
    Shap.sample_explain_df,
    interaction_index=None,
)

# %% [markdown]
# ## Embedding Analysis

# %% [markdown]
# The column `face_amount_band` was embedded to have the neural network learn the relationships of this column naturally instead of using an encoding such as ordinal or nominal. To understand the embeddings better, the weights of the embeddings were extracted and then analyzed using cosine similarity, pca, or t-sne. As seen the embeddings are 6 dimensions.

# %%
model.embedding_get_weights("face_amount_band")
# Out:
#                            dim_0  dim_1  dim_2  dim_3  dim_4  dim_5
# 01: 0 - 9,999               0.14  -0.59  -0.61  -0.48   0.99   0.87
# 02: 10,000 - 24,999         0.23  -0.87  -0.24  -0.50   1.03   0.62
# 03: 25,000 - 49,999         0.59  -1.04  -0.32  -0.30   0.46   0.75
# 04: 50,000 - 99,999         0.91  -0.92  -0.23  -0.32   0.47   0.55
# 05: 100,000 - 249,999       1.03  -0.71  -0.12  -0.28   0.77  -0.00
# 06: 250,000 - 499,999       0.74  -0.90  -0.45   0.30   0.49  -0.03
# 07: 500,000 - 999,999       0.42  -0.29  -0.65   0.56   0.52   0.22
# 08: 1,000,000 - 2,499,999  -0.02   0.05  -0.41   0.69   0.77   0.01
# 09: 2,500,000 - 4,999,999   0.29   0.39   0.13   0.46  -0.43   0.84
# 10: 5,000,000 - 9,999,999  -0.35  -0.16   1.17   0.33  -0.25   0.45
# 11: 10,000,000+            -0.84  -0.01   0.03  -1.00  -0.66  -0.06
# __UNK__                     0.13  -0.57  -0.12  -0.53  -0.40  -0.02

# %% [markdown]
# The relationships show that face amounts close to eachother are more similar to ones that are farther apart. The PCA analysis shows that the 2.5M+ face bands are the farthest apart from other face bands

# %%
model.embedding_plot_similarity("face_amount_band")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="83596949-67be-4ef9-ae8b-c14d50bd02b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("83596949-67be-4ef9-ae8b-c14d50bd02b2")) {                    Plotly.newPlot(                        "83596949-67be-4ef9-ae8b-c14d50bd02b2",                        [{"coloraxis":"coloraxis","name":"0","x":["01: 0 - 9,999","02: 10,000 - 24,999","03: 25,000 - 49,999","04: 50,000 - 99,999","05: 100,000 - 249,999","06: 250,000 - 499,999","07: 500,000 - 999,999","08: 1,000,000 - 2,499,999","09: 2,500,000 - 4,999,999","10: 5,000,000 - 9,999,999","11: 10,000,000+"],"y":["01: 0 - 9,999","02: 10,000 - 24,999","03: 25,000 - 49,999","04: 50,000 - 99,999","05: 100,000 - 249,999","06: 250,000 - 499,999","07: 500,000 - 999,999","08: 1,000,000 - 2,499,999","09: 2,500,000 - 4,999,999","10: 5,000,000 - 9,999,999","11: 10,000,000+"],"z":{"dtype":"f4","bdata":"AACAP+9dcj+mllc\u002fJYxBP4swHz8C6wo\u002fRWwPP0LQuD6FHsK9ulmcvjE2GL7vXXI\u002f\u002f\u002f9\u002fP9ioYz\u002f+WFU\u002f1oFBP+C2Ij9SrPk+PlaTPqAieL4s9i2+ZnQ1vqaWVz\u002fYqGM\u002fAQCAP5Pcdj+DNUg\u002fpG9EP4MNDz8Eigc+GLVIPCfcDr5K6Xe+JYxBP\u002f5YVT+T3HY\u002f\u002f\u002f9\u002fP4kXZj9Z3lE\u002fJX4PP3KB2z2uOLq7xlZMvjpWtb6LMB8\u002f1oFBP4M1SD+JF2Y\u002f\u002f\u002f9\u002fPxy2WD9fsA4\u002fX0ZyPlaRhL6ffKW+h3v\u002fvgLrCj\u002fgtiI\u002fpG9EP1neUT8ctlg\u002fAACAP4sQUD+ui+w+MCs4vt4et758FR+\u002fRWwPP1Ks+T6DDQ8\u002fJX4PP1+wDj+LEFA\u002fAACAP4xATz9A8dk9BXLmvmNtRL9C0Lg+PlaTPgSKBz5ygds9X0ZyPq6L7D6MQE8\u002fAACAPzRXBL1xZJO+JxU7v4Uewr2gIni+GLVIPK44urtWkYS+MCs4vkDx2T00VwS9AACAP0Kkxz5WJY2+ulmcviz2Lb4n3A6+xlZMvp98pb7eHre+BXLmvnFkk75CpMc+AACAPxGXhj0xNhi+ZnQ1vkrpd746VrW+h3v\u002fvnwVH79jbUS\u002fJxU7v1Yljb4Rl4Y9\u002f\u002f9\u002fPw==","shape":"11, 11"},"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ecolor: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorsc ...

# %%
model.embedding_plot_2d("face_amount_band", method="pca")
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="489a3433-3a9e-4173-883d-b17b7e5cf5d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("489a3433-3a9e-4173-883d-b17b7e5cf5d4")) {                    Plotly.newPlot(                        "489a3433-3a9e-4173-883d-b17b7e5cf5d4",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ecategory=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","orientation":"v","showlegend":false,"text":["01: 0 - 9,999","02: 10,000 - 24,999","03: 25,000 - 49,999","04: 50,000 - 99,999","05: 100,000 - 249,999","06: 250,000 - 499,999","07: 500,000 - 999,999","08: 1,000,000 - 2,499,999","09: 2,500,000 - 4,999,999","10: 5,000,000 - 9,999,999","11: 10,000,000+"],"x":{"dtype":"f4","bdata":"MQEUP6V6Gz\u002ffIhA\u002fxVEjPxU\u002fNz\u002f59BU\u002f8eJ+PvYDz70J\u002fHq\u002fsnW0v6oKub8="},"xaxis":"x","y":{"dtype":"f4","bdata":"gQrpvp3KBL\u002fPH7K+O\u002fZovt4YCr1M37A+llctP7bRTj+9Wx8\u002ft\u002fZAPr55h78="},"yaxis":"y","type":"scatter","textposition":"top center"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmod ...

# %%
charters.pdp(
    model=model,
    df=md_encoded[((md_encoded["duration"] <= 30))],
    x_axis="face_amount_band",
    weight="amount_exposed",
    mapping=mapping,
    display=True,
)
# Out:
#  2026-01-26 04:28:33 | morai.experience.charters | INFO     | Model: [Neural] for partial dependence plot.
#  2026-01-26 04:28:33 | morai.experience.charters | INFO     | Weights: [amount_exposed]
#  2026-01-26 04:28:33 | morai.experience.charters | INFO     | x_axis: [face_amount_band] type: [passthrough] center: [global]
#  2026-01-26 04:28:34 | morai.experience.charters | INFO     | Creating 11 predictions.
# Processing:   0%|          | 0/11 [00:00<?, ?combo/s]
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="fabee8e1-0573-46c3-bd12-4adf430bd11c" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("fabee8e1-0573-46c3-bd12-4adf430bd11c")) {                    Plotly.newPlot(                        "fabee8e1-0573-46c3-bd12-4adf430bd11c",                        [{"line":{"color":"#FD3216"},"mode":"lines","name":"Overall","x":["01: 0 - 9,999","02: 10,000 - 24,999","03: 25,000 - 49,999","04: 50,000 - 99,999","05: 100,000 - 249,999","06: 250,000 - 499,999","07: 500,000 - 999,999","08: 1,000,000 - 2,499,999","09: 2,500,000 - 4,999,999","10: 5,000,000 - 9,999,999","11: 10,000,000+"],"y":{"dtype":"f8","bdata":"eoE2ctR89z8yKHTtufb1PxchD7LcVPM\u002f4s3NpCzh8D9ogHWLbcftPyN1Iip0zOs\u002f8ZSt2+K96j\u002fVfjAF8t3qP+Jr\u002f\u002foR\u002f+k\u002fNBRVVRs06T9RRSas7EnqPw=="},"type":"scatter","xaxis":"x","yaxis":"y"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"patter ...

# %% [markdown]
# # Reload

# %%
import importlib

# %%
importlib.reload(neural)
